# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# print(weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = weather_api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# print(url)

# %%
# cities_df = pd.DataFrame (cities,columns=['City Name'])
# cities_df
# print(cities_df)
# num_cities = len(cities_df)
# num_cities


record_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
print('------------------------')
print('Beginning Weather Check')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
#     if record_counter <= num_cities:
    record_counter += 1

    print('Retrieving data from city of {} ==> Record {}'.format(city, record_counter))

print('-------------------------')
print('Finished weather check')
print('-------------------------')
# Out:
# ------------------------
# Beginning Weather Check
# ------------------------
# Retrieving data from city of ponta do sol | Record 1
# Retrieving data from city of posse | Record 2
# Retrieving data from city of weymouth | Record 3
# Retrieving data from city of punta arenas | Record 4
# Retrieving data from city of rikitea | Record 5
# Retrieving data from city of kaka | Record 6
# Retrieving data from city of busselton | Record 7
# Retrieving data from city of ushuaia | Record 8
# Retrieving data from city of labuhan | Record 9
# Retrieving data from city of dingle | Record 10
# Retrieving data from city of altamira | Record 11
# Retrieving data from city of duku | Record 12
# Retrieving data from city of santa isabel do rio negro | Record 13
# Retrieving data from city of olinala | Record 14
# Retrieving data from city of tasiilaq | Record 15
# Retrieving data from city of airai | Record 16
# Retrieving data from city of lasa | Record 17
# Retrieving data from city of albany | Record 18
# Retrieving data from city of guerrero negro | Record 19
# Retrieving data from city of keti bandar | Record 20
# Retrieving data from city of pangnirtung | Record 21
# Retrieving data from city of taolanaro | Record 22
# Retrieving data from city of alenquer | Record 23
# Retrieving data from city of husavik | Record 24
# Retrieving data from city of tsihombe | Record 25
# Retrieving data from city of lolua | Record 26
# Retrieving data from city of archidona | Record 27
# Retrieving data from city of luau | Record 28
# Retrieving data from city of salalah | Record 29
# Retrieving data from city of novoanninskiy | Record 30
# Retrieving data from city of cayenne | Record 31
# Retrieving data from city of doctor pedro p. pena | Record 32
# Retrieving data from city of bredasdorp | Record 33
# Retrieving data from city of krasnoselkup | Record 34
# Retrieving data from city of castro | Record 35
# Retrieving data from city of mataura | Record 36
# Retrieving data from city of kuandian | Record 37
# Retrieving data from city of lagoa | Record 38
# Retrieving data from city of poum | Record 39
# Retrieving data from city of barentsburg | Record 40
# Retrieving data from city of kruisfontein | Record 41
# Retrieving data from city of narsaq | Record 42
# Retrieving data from city of yellowknife | Record 43
# Retrieving data from city of jaisalmer | Record 44
# Retrieving data from city of port arthur | Record 45
# Retrieving data from city of hobyo | Record 46
# Retrieving data from city of mahebourg | Record 47
# Retrieving data from city of port alfred | Record 48
# Retrieving data from city of columbus | Record 49
# Retrieving data from city of mugur-aksy | Record 50
# Retrieving data from city of high level | Record 51
# Retrieving data from city of rapid valley | Record 52
# Retrieving data from city of palu | Record 53
# Retrieving data from city of eureka | Record 54
# Retrieving data from city of mikuni | Record 55
# Retrieving data from city of tuktoyaktuk | Record 56
# Retrieving data from city of netivot | Record 57
# Retrieving data from city of tuatapere | Record 58
# Retrieving data from city of vaini | Record 59
# Retrieving data from city of aklavik | Record 60
# Retrieving data from city of soe | Record 61
# Retrieving data from city of hamilton | Record 62
# Retrieving data from city of qaqortoq | Record 63
# Retrieving data from city of saint-philippe | Record 64
# Retrieving data from city of lajas | Record 65
# Retrieving data from city of san carlos de bariloche | Record 66
# Retrieving data from city of harper | Record 67
# Retrieving data from city of ca mau | Record 68
# Retrieving data from city of awjilah | Record 69
# Retrieving data from city of pandaria | Record 70
# Retrieving data from city of aloleng | Record 71
# Retrieving data from city of puerto quijarro | Record 72
# Retrieving data from city of nurota | Record 73
# Retrieving data from city of alyangula | Record 74
# Retrieving data from city of bluff | Record 75
# Retrieving data from city of nisia floresta | Record 76
# Retrieving data from city of hobart | Record 77
# Retrieving data from city of nome | Record 78
# Retrieving data from city of mabaruma | Record 79
# Retrieving data from city of bengkulu | Record 80
# Retrieving data from city of yumen | Record 81
# Retrieving data from city of grand river south east | Record 82
# Retrieving data from city of north branch | Record 83
# Retrieving data from city of ariquemes | Record 84
# Retrieving data from city of cabo san lucas | Record 85
# Retrieving data from city of kapaa | Record 86
# Retrieving data from city of san cristobal | Record 87
# Retrieving data from city of faya | Record 88
# Retrieving data from city of hermanus | Record 89
# Retrieving data from city of tabiauea | Record 90
# Retrieving data from city of georgetown | Record 91
# Retrieving data from city of esperance | Record 92
# Retrieving data from city of isangel | Record 93
# Retrieving data from city of port-gentil | Record 94
# Retrieving data from city of henties bay | Record 95
# Retrieving data from city of torbay | Record 96
# Retrieving data from city of barrow | Record 97
# Retrieving data from city of nyagan | Record 98
# Retrieving data from city of hasaki | Record 99
# Retrieving data from city of angatuba | Record 100
# Retrieving data from city of atuona | Record 101
# Retrieving data from city of kaitangata | Record 102
# Retrieving data from city of kieta | Record 103
# Retrieving data from city of saldanha | Record 104
# Retrieving data from city of saskylakh | Record 105
# Retrieving data from city of del rio | Record 106
# Retrieving data from city of lebu | Record 107
# Retrieving data from city of morgan city | Record 108
# Retrieving data from city of jalu | Record 109
# Retrieving data from city of cape town | Record 110
# Retrieving data from city of kodiak | Record 111
# Retrieving data from city of sinkat | Record 112
# Retrieving data from city of ilulissat | Record 113
# Retrieving data from city of konstantinovka | Record 114
# Retrieving data from city of butaritari | Record 115
# Retrieving data from city of hithadhoo | Record 116
# Retrieving data from city of maldonado | Record 117
# Retrieving data from city of nikolskoye | Record 118
# Retrieving data from city of puerto ayora | Record 119
# Retrieving data from city of antofagasta | Record 120
# Retrieving data from city of kavieng | Record 121
# Retrieving data from city of hilo | Record 122
# Retrieving data from city of tuggurt | Record 123
# Retrieving data from city of itarema | Record 124
# Retrieving data from city of bakchar | Record 125
# Retrieving data from city of mehamn | Record 126
# Retrieving data from city of anloga | Record 127
# Retrieving data from city of naze | Record 128
# Retrieving data from city of sentyabrskiy | Record 129
# Retrieving data from city of alofi | Record 130
# Retrieving data from city of sehithwa | Record 131
# Retrieving data from city of tiksi | Record 132
# Retrieving data from city of acarau | Record 133
# Retrieving data from city of belushya guba | Record 134
# Retrieving data from city of dickinson | Record 135
# Retrieving data from city of la orilla | Record 136
# Retrieving data from city of enumclaw | Record 137
# Retrieving data from city of fukue | Record 138
# Retrieving data from city of east london | Record 139
# Retrieving data from city of san patricio | Record 140
# Retrieving data from city of upernavik | Record 141
# Retrieving data from city of boa vista | Record 142
# Retrieving data from city of santa cruz | Record 143
# Retrieving data from city of khani | Record 144
# Retrieving data from city of anori | Record 145
# Retrieving data from city of ust-tsilma | Record 146
# Retrieving data from city of barcelos | Record 147
# Retrieving data from city of mount gambier | Record 148
# Retrieving data from city of tasgaon | Record 149
# Retrieving data from city of provideniya | Record 150
# Retrieving data from city of amderma | Record 151
# Retrieving data from city of kalabo | Record 152
# Retrieving data from city of vostok | Record 153
# Retrieving data from city of beringovskiy | Record 154
# Retrieving data from city of bobonong | Record 155
# Retrieving data from city of new norfolk | Record 156
# Retrieving data from city of dymer | Record 157
# Retrieving data from city of campo verde | Record 158
# Retrieving data from city of carnarvon | Record 159
# Retrieving data from city of raudeberg | Record 160
# Retrieving data from city of avarua | Record 161
# Retrieving data from city of tumannyy | Record 162
# Retrieving data from city of tiarei | Record 163
# Retrieving data from city of cesme | Record 164
# Retrieving data from city of santiago | Record 165
# Retrieving data from city of balkanabat | Record 166
# Retrieving data from city of zhanaozen | Record 167
# Retrieving data from city of san quintin | Record 168
# Retrieving data from city of sitka | Record 169
# Retrieving data from city of tete | Record 170
# Retrieving data from city of vaitupu | Record 171
# Retrieving data from city of plettenberg bay | Record 172
# Retrieving data from city of haines junction | Record 173
# Retrieving data from city of manama | Record 174
# Retrieving data from city of sao joao do piaui | Record 175
# Retrieving data from city of champerico | Record 176
# Retrieving data from city of ola | Record 177
# Retrieving data from city of curuguaty | Record 178
# Retrieving data from city of longyearbyen | Record 179
# Retrieving data from city of phalaborwa | Record 180
# Retrieving data from city of severo-kurilsk | Record 181
# Retrieving data from city of molchanovo | Record 182
# Retrieving data from city of thompson | Record 183
# Retrieving data from city of hambantota | Record 184
# Retrieving data from city of farafangana | Record 185
# Retrieving data from city of mareeba | Record 186
# Retrieving data from city of mount isa | Record 187
# Retrieving data from city of sheltozero | Record 188
# Retrieving data from city of mar del plata | Record 189
# Retrieving data from city of grindavik | Record 190
# Retrieving data from city of vagur | Record 191
# Retrieving data from city of saleaula | Record 192
# Retrieving data from city of lazurne | Record 193
# Retrieving data from city of sakakah | Record 194
# Retrieving data from city of olga | Record 195
# Retrieving data from city of lianran | Record 196
# Retrieving data from city of sao joao da barra | Record 197
# Retrieving data from city of tapaua | Record 198
# Retrieving data from city of hendijan | Record 199
# Retrieving data from city of samarai | Record 200
# Retrieving data from city of tabou | Record 201
# Retrieving data from city of clyde river | Record 202
# Retrieving data from city of salta | Record 203
# Retrieving data from city of faanui | Record 204
# Retrieving data from city of melivoia | Record 205
# Retrieving data from city of harlingen | Record 206
# Retrieving data from city of englehart | Record 207
# Retrieving data from city of zimapan | Record 208
# Retrieving data from city of puerto cabezas | Record 209
# Retrieving data from city of cherskiy | Record 210
# Retrieving data from city of mecca | Record 211
# Retrieving data from city of fevralsk | Record 212
# Retrieving data from city of biloela | Record 213
# Retrieving data from city of sao miguel do araguaia | Record 214
# Retrieving data from city of samaniego | Record 215
# Retrieving data from city of rassvet | Record 216
# Retrieving data from city of san jose | Record 217
# Retrieving data from city of road town | Record 218
# Retrieving data from city of illoqqortoormiut | Record 219
# Retrieving data from city of havoysund | Record 220
# Retrieving data from city of one hundred mile house | Record 221
# Retrieving data from city of pisco | Record 222
# Retrieving data from city of aksu | Record 223
# Retrieving data from city of sur | Record 224
# Retrieving data from city of bossier city | Record 225
# Retrieving data from city of pirogovo | Record 226
# Retrieving data from city of srivardhan | Record 227
# Retrieving data from city of warqla | Record 228
# Retrieving data from city of sao filipe | Record 229
# Retrieving data from city of jamestown | Record 230
# Retrieving data from city of norman wells | Record 231
# Retrieving data from city of makaha | Record 232
# Retrieving data from city of qaanaaq | Record 233
# Retrieving data from city of kavaratti | Record 234
# Retrieving data from city of devonport | Record 235
# Retrieving data from city of san policarpo | Record 236
# Retrieving data from city of batouri | Record 237
# Retrieving data from city of sao felix do xingu | Record 238
# Retrieving data from city of turkistan | Record 239
# Retrieving data from city of mujiayingzi | Record 240
# Retrieving data from city of anadyr | Record 241
# Retrieving data from city of arraial do cabo | Record 242
# Retrieving data from city of nanortalik | Record 243
# Retrieving data from city of itaituba | Record 244
# Retrieving data from city of hovd | Record 245
# Retrieving data from city of scottsbluff | Record 246
# Retrieving data from city of turukhansk | Record 247
# Retrieving data from city of caceres | Record 248
# Retrieving data from city of bambous virieux | Record 249
# Retrieving data from city of zhangdian | Record 250
# Retrieving data from city of bellevue | Record 251
# Retrieving data from city of bolshegrivskoye | Record 252
# Retrieving data from city of lata | Record 253
# Retrieving data from city of touros | Record 254
# Retrieving data from city of khatanga | Record 255
# Retrieving data from city of riyadh | Record 256
# Retrieving data from city of isiro | Record 257
# Retrieving data from city of iqaluit | Record 258
# Retrieving data from city of atar | Record 259
# Retrieving data from city of fengzhen | Record 260
# Retrieving data from city of louisbourg | Record 261
# Retrieving data from city of ternovka | Record 262
# Retrieving data from city of gorontalo | Record 263
# Retrieving data from city of daura | Record 264
# Retrieving data from city of san jose de comayagua | Record 265
# Retrieving data from city of gurskoye | Record 266
# Retrieving data from city of port lincoln | Record 267
# Retrieving data from city of washington | Record 268
# Retrieving data from city of attawapiskat | Record 269
# Retrieving data from city of ribeira grande | Record 270
# Retrieving data from city of chingirlau | Record 271
# Retrieving data from city of constitucion | Record 272
# Retrieving data from city of bardiyah | Record 273
# Retrieving data from city of vanimo | Record 274
# Retrieving data from city of olafsvik | Record 275
# Retrieving data from city of lazaro cardenas | Record 276
# Retrieving data from city of saint paul | Record 277
# Retrieving data from city of victoria | Record 278
# Retrieving data from city of gushikawa | Record 279
# Retrieving data from city of luderitz | Record 280
# Retrieving data from city of warrnambool | Record 281
# Retrieving data from city of athabasca | Record 282
# Retrieving data from city of duldurga | Record 283
# Retrieving data from city of chabahar | Record 284
# Retrieving data from city of oussouye | Record 285
# Retrieving data from city of port elizabeth | Record 286
# Retrieving data from city of dalvik | Record 287
# Retrieving data from city of filingue | Record 288
# Retrieving data from city of kosh-agach | Record 289
# Retrieving data from city of mandalgovi | Record 290
# Retrieving data from city of catamarca | Record 291
# Retrieving data from city of saint george | Record 292
# Retrieving data from city of kutum | Record 293
# Retrieving data from city of rovaniemi | Record 294
# Retrieving data from city of pinsk | Record 295
# Retrieving data from city of tessalit | Record 296
# Retrieving data from city of vila velha | Record 297
# Retrieving data from city of namatanai | Record 298
# Retrieving data from city of racale | Record 299
# Retrieving data from city of muros | Record 300
# Retrieving data from city of rio gallegos | Record 301
# Retrieving data from city of puerto baquerizo moreno | Record 302
# Retrieving data from city of sao jose do belmonte | Record 303
# Retrieving data from city of sindon | Record 304
# Retrieving data from city of vilyuysk | Record 305
# Retrieving data from city of srednekolymsk | Record 306
# Retrieving data from city of celestun | Record 307
# Retrieving data from city of mokhotlong | Record 308
# Retrieving data from city of shenjiamen | Record 309
# Retrieving data from city of geraldton | Record 310
# Retrieving data from city of rawlins | Record 311
# Retrieving data from city of maniitsoq | Record 312
# Retrieving data from city of kurchum | Record 313
# Retrieving data from city of micheweni | Record 314
# Retrieving data from city of ostrovnoy | Record 315
# Retrieving data from city of uglegorsk | Record 316
# Retrieving data from city of honningsvag | Record 317
# Retrieving data from city of thunder bay | Record 318
# Retrieving data from city of dikson | Record 319
# Retrieving data from city of chuy | Record 320
# Retrieving data from city of baykit | Record 321
# Retrieving data from city of nipawin | Record 322
# Retrieving data from city of dawei | Record 323
# Retrieving data from city of shingu | Record 324
# Retrieving data from city of aljezur | Record 325
# Retrieving data from city of khash | Record 326
# Retrieving data from city of bathsheba | Record 327
# Retrieving data from city of dzhusaly | Record 328
# Retrieving data from city of kiruna | Record 329
# Retrieving data from city of gerash | Record 330
# Retrieving data from city of fairbanks | Record 331
# Retrieving data from city of sept-iles | Record 332
# Retrieving data from city of redcar | Record 333
# Retrieving data from city of college | Record 334
# Retrieving data from city of gumusyaka | Record 335
# Retrieving data from city of barawe | Record 336
# Retrieving data from city of nemuro | Record 337
# Retrieving data from city of nangwa | Record 338
# Retrieving data from city of coquimbo | Record 339
# Retrieving data from city of imbituba | Record 340
# Retrieving data from city of kudahuvadhoo | Record 341
# Retrieving data from city of fort nelson | Record 342
# Retrieving data from city of marzuq | Record 343
# Retrieving data from city of sao domingos | Record 344
# Retrieving data from city of biak | Record 345
# Retrieving data from city of gurgan | Record 346
# Retrieving data from city of nizwa | Record 347
# Retrieving data from city of stawell | Record 348
# Retrieving data from city of bethel | Record 349
# Retrieving data from city of westport | Record 350
# Retrieving data from city of marsaxlokk | Record 351
# Retrieving data from city of ajka | Record 352
# Retrieving data from city of prince rupert | Record 353
# Retrieving data from city of yaan | Record 354
# Retrieving data from city of horta | Record 355
# Retrieving data from city of portland | Record 356
# Retrieving data from city of carballo | Record 357
# Retrieving data from city of baculin | Record 358
# Retrieving data from city of young | Record 359
# Retrieving data from city of rungata | Record 360
# Retrieving data from city of karratha | Record 361
# Retrieving data from city of wangaratta | Record 362
# Retrieving data from city of maragogi | Record 363
# Retrieving data from city of murupara | Record 364
# Retrieving data from city of la ronge | Record 365
# Retrieving data from city of soma | Record 366
# Retrieving data from city of mamallapuram | Record 367
# Retrieving data from city of saint-georges | Record 368
# Retrieving data from city of sretensk | Record 369
# Retrieving data from city of caazapa | Record 370
# Retrieving data from city of port pirie | Record 371
# Retrieving data from city of lavrentiya | Record 372
# Retrieving data from city of caiaponia | Record 373
# Retrieving data from city of lumatil | Record 374
# Retrieving data from city of fortuna | Record 375
# Retrieving data from city of marawi | Record 376
# Retrieving data from city of deputatskiy | Record 377
# Retrieving data from city of hima | Record 378
# Retrieving data from city of kupang | Record 379
# Retrieving data from city of warmbad | Record 380
# Retrieving data from city of veselynove | Record 381
# Retrieving data from city of paradwip | Record 382
# Retrieving data from city of hermon | Record 383
# Retrieving data from city of dauphin | Record 384
# Retrieving data from city of barra do garcas | Record 385
# Retrieving data from city of nalut | Record 386
# Retrieving data from city of bargal | Record 387
# Retrieving data from city of mackay | Record 388
# Retrieving data from city of kaabong | Record 389
# Retrieving data from city of eshowe | Record 390
# Retrieving data from city of eyl | Record 391
# Retrieving data from city of ust-maya | Record 392
# Retrieving data from city of necochea | Record 393
# Retrieving data from city of fare | Record 394
# Retrieving data from city of tura | Record 395
# Retrieving data from city of westminster | Record 396
# Retrieving data from city of curico | Record 397
# Retrieving data from city of itatskiy | Record 398
# Retrieving data from city of lorengau | Record 399
# Retrieving data from city of jaciara | Record 400
# Retrieving data from city of tambacounda | Record 401
# Retrieving data from city of atlantic city | Record 402
# Retrieving data from city of cabedelo | Record 403
# Retrieving data from city of pevek | Record 404
# Retrieving data from city of romanovo | Record 405
# Retrieving data from city of bani | Record 406
# Retrieving data from city of mys shmidta | Record 407
# Retrieving data from city of codrington | Record 408
# Retrieving data from city of texarkana | Record 409
# Retrieving data from city of benghazi | Record 410
# Retrieving data from city of namibe | Record 411
# Retrieving data from city of batemans bay | Record 412
# Retrieving data from city of nouakchott | Record 413
# Retrieving data from city of vardo | Record 414
# Retrieving data from city of saint-augustin | Record 415
# Retrieving data from city of katsuura | Record 416
# Retrieving data from city of teknaf | Record 417
# Retrieving data from city of freeport | Record 418
# Retrieving data from city of komsomolskiy | Record 419
# Retrieving data from city of kostinbrod | Record 420
# Retrieving data from city of skelleftea | Record 421
# Retrieving data from city of sisimiut | Record 422
# Retrieving data from city of adeje | Record 423
# Retrieving data from city of sindor | Record 424
# Retrieving data from city of saint-denis | Record 425
# Retrieving data from city of san vicente | Record 426
# Retrieving data from city of oktyabrskiy | Record 427
# Retrieving data from city of miami beach | Record 428
# Retrieving data from city of ayagoz | Record 429
# Retrieving data from city of birao | Record 430
# Retrieving data from city of tahta | Record 431
# Retrieving data from city of aasiaat | Record 432
# Retrieving data from city of berezovyy | Record 433
# Retrieving data from city of marsh harbour | Record 434
# Retrieving data from city of bokoro | Record 435
# Retrieving data from city of toccoa | Record 436
# Retrieving data from city of hendrina | Record 437
# Retrieving data from city of bokspits | Record 438
# Retrieving data from city of astipalaia | Record 439
# Retrieving data from city of whitehorse | Record 440
# Retrieving data from city of antalaha | Record 441
# Retrieving data from city of stare mesto | Record 442
# Retrieving data from city of eskisehir | Record 443
# Retrieving data from city of marystown | Record 444
# Retrieving data from city of sainte-rose | Record 445
# Retrieving data from city of pouembout | Record 446
# Retrieving data from city of buala | Record 447
# Retrieving data from city of padilla | Record 448
# Retrieving data from city of padang | Record 449
# Retrieving data from city of barabash | Record 450
# Retrieving data from city of basoko | Record 451
# Retrieving data from city of bur gabo | Record 452
# Retrieving data from city of barranca | Record 453
# Retrieving data from city of praxedis guerrero | Record 454
# Retrieving data from city of pindi gheb | Record 455
# Retrieving data from city of zlobin | Record 456
# Retrieving data from city of ibra | Record 457
# Retrieving data from city of dingzhou | Record 458
# Retrieving data from city of leh | Record 459
# Retrieving data from city of pilibanga | Record 460
# Retrieving data from city of najran | Record 461
# Retrieving data from city of guiyang | Record 462
# Retrieving data from city of portsmouth | Record 463
# Retrieving data from city of dunedin | Record 464
# Retrieving data from city of uchiza | Record 465
# Retrieving data from city of bitung | Record 466
# Retrieving data from city of pangkalanbuun | Record 467
# Retrieving data from city of bud | Record 468
# Retrieving data from city of saint-pierre | Record 469
# Retrieving data from city of mogocha | Record 470
# Retrieving data from city of katangli | Record 471
# Retrieving data from city of calvia | Record 472
# Retrieving data from city of slave lake | Record 473
# Retrieving data from city of iquique | Record 474
# Retrieving data from city of verkhnevilyuysk | Record 475
# Retrieving data from city of trinidad | Record 476
# Retrieving data from city of kiama | Record 477
# Retrieving data from city of moree | Record 478
# Retrieving data from city of sorland | Record 479
# Retrieving data from city of high prairie | Record 480
# Retrieving data from city of salo | Record 481
# Retrieving data from city of shar | Record 482
# Retrieving data from city of jiuquan | Record 483
# Retrieving data from city of lumphat | Record 484
# Retrieving data from city of honiton | Record 485
# Retrieving data from city of perth | Record 486
# Retrieving data from city of porto empedocle | Record 487
# Retrieving data from city of olinda | Record 488
# Retrieving data from city of ewa beach | Record 489
# Retrieving data from city of hofn | Record 490
# Retrieving data from city of lompoc | Record 491
# Retrieving data from city of rivera | Record 492
# Retrieving data from city of taoudenni | Record 493
# Retrieving data from city of kattivakkam | Record 494
# Retrieving data from city of nanakuli | Record 495
# Retrieving data from city of yerbogachen | Record 496
# Retrieving data from city of dharchula | Record 497
# Retrieving data from city of praia da vitoria | Record 498
# Retrieving data from city of tulum | Record 499
# Retrieving data from city of wahran | Record 500
# Retrieving data from city of cowra | Record 501
# Retrieving data from city of dong hoi | Record 502
# Retrieving data from city of flinders | Record 503
# Retrieving data from city of adra | Record 504
# Retrieving data from city of shimoda | Record 505
# Retrieving data from city of vidim | Record 506
# Retrieving data from city of talnakh | Record 507
# Retrieving data from city of ahipara | Record 508
# Retrieving data from city of ous | Record 509
# Retrieving data from city of benguela | Record 510
# Retrieving data from city of abu kamal | Record 511
# Retrieving data from city of altay | Record 512
# Retrieving data from city of hargeysa | Record 513
# Retrieving data from city of tome-acu | Record 514
# Retrieving data from city of chiang klang | Record 515
# Retrieving data from city of coahuayana | Record 516
# Retrieving data from city of skagastrond | Record 517
# Retrieving data from city of santa fe | Record 518
# Retrieving data from city of chambas | Record 519
# Retrieving data from city of wilmington | Record 520
# Retrieving data from city of trogir | Record 521
# Retrieving data from city of aqtobe | Record 522
# Retrieving data from city of souillac | Record 523
# Retrieving data from city of kununurra | Record 524
# Retrieving data from city of muyezerskiy | Record 525
# Retrieving data from city of cotonou | Record 526
# Retrieving data from city of cukai | Record 527
# Retrieving data from city of nago | Record 528
# Retrieving data from city of popondetta | Record 529
# Retrieving data from city of rundu | Record 530
# Retrieving data from city of ponta delgada | Record 531
# Retrieving data from city of mangrol | Record 532
# Retrieving data from city of les cayes | Record 533
# Retrieving data from city of maralal | Record 534
# Retrieving data from city of chokurdakh | Record 535
# Retrieving data from city of panorama | Record 536
# Retrieving data from city of aflu | Record 537
# Retrieving data from city of impfondo | Record 538
# Retrieving data from city of pergamino | Record 539
# Retrieving data from city of richards bay | Record 540
# Retrieving data from city of birsk | Record 541
# Retrieving data from city of zhigansk | Record 542
# Retrieving data from city of cidreira | Record 543
# Retrieving data from city of quatre cocos | Record 544
# Retrieving data from city of puerto gaitan | Record 545
# Retrieving data from city of yichang | Record 546
# Retrieving data from city of jujuy | Record 547
# Retrieving data from city of skovorodino | Record 548
# Retrieving data from city of mirzapur | Record 549
# Retrieving data from city of sabang | Record 550
# Retrieving data from city of broken hill | Record 551
# Retrieving data from city of lushunkou | Record 552
# Retrieving data from city of vrangel | Record 553
# Retrieving data from city of hualmay | Record 554
# Retrieving data from city of mullaitivu | Record 555
# Retrieving data from city of riberalta | Record 556
# Retrieving data from city of roma | Record 557
# Retrieving data from city of bilisht | Record 558
# Retrieving data from city of nizhneyansk | Record 559
# Retrieving data from city of malakal | Record 560
# Retrieving data from city of serenje | Record 561
# Retrieving data from city of paamiut | Record 562
# Retrieving data from city of monrovia | Record 563
# Retrieving data from city of springbok | Record 564
# Retrieving data from city of vallenar | Record 565
# Retrieving data from city of seymchan | Record 566
# Retrieving data from city of belmonte | Record 567
# Retrieving data from city of dayong | Record 568
# Retrieving data from city of solnechnyy | Record 569
# Retrieving data from city of jumla | Record 570
# Retrieving data from city of grafton | Record 571
# Retrieving data from city of toamasina | Record 572
# Retrieving data from city of nhulunbuy | Record 573
# Retrieving data from city of dobre miasto | Record 574
# Retrieving data from city of templin | Record 575
# Retrieving data from city of klaksvik | Record 576
# Retrieving data from city of velluru | Record 577
# Retrieving data from city of dera bugti | Record 578
# Retrieving data from city of barra | Record 579
# Retrieving data from city of bonavista | Record 580
# Retrieving data from city of mwinilunga | Record 581
# Retrieving data from city of cam ranh | Record 582
# Retrieving data from city of pospelikha | Record 583
# Retrieving data from city of victor harbor | Record 584
# Retrieving data from city of poso | Record 585
# Retrieving data from city of brcko | Record 586
# Retrieving data from city of cortez | Record 587
# Retrieving data from city of matara | Record 588
# Retrieving data from city of inhambane | Record 589
# Retrieving data from city of puerto del rosario | Record 590
# Retrieving data from city of hami | Record 591
# Retrieving data from city of batticaloa | Record 592
# Retrieving data from city of aberdeen | Record 593
# Retrieving data from city of steinbach | Record 594
# Retrieving data from city of simao | Record 595
# Retrieving data from city of alice springs | Record 596
# Retrieving data from city of dobryanka | Record 597
# Retrieving data from city of oranjemund | Record 598
# Retrieving data from city of payakumbuh | Record 599
# Retrieving data from city of porbandar | Record 600
# Retrieving data from city of aguimes | Record 601
# Retrieving data from city of omboue | Record 602
# Retrieving data from city of porosozero | Record 603
# Retrieving data from city of atikokan | Record 604
# Retrieving data from city of cockburn town | Record 605
# Retrieving data from city of waddan | Record 606
# Retrieving data from city of montpellier | Record 607
# Retrieving data from city of bogorodskoye | Record 608
# Retrieving data from city of kamenskoye | Record 609
# Retrieving data from city of broome | Record 610
# Retrieving data from city of shitanjing | Record 611
# Retrieving data from city of troitsko-pechorsk | Record 612
# Retrieving data from city of jaysingpur | Record 613
# Retrieving data from city of banda aceh | Record 614
# Retrieving data from city of maridi | Record 615
# Retrieving data from city of oblivskaya | Record 616
# Retrieving data from city of balimo | Record 617
# Retrieving data from city of falealupo | Record 618
# Retrieving data from city of acapulco | Record 619
# Retrieving data from city of hayden | Record 620
# Retrieving data from city of puksoozero | Record 621
# Retrieving data from city of beatrice | Record 622
# Retrieving data from city of shakawe | Record 623
# -------------------------
# Finished weather check
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
