# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

print(weather_api_key)
# Out:
# 99f96a0396de356f1b82d64d481006c5

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1300)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1300)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# print(cities)
# Out:
# 581

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = weather_api_key
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + api_key

# Create empty lists to append the API data into lists 
city_list = []
country_list = []
lat_list = []
lng_list = []
temperature_list = []
cloud_list = []
humidity_list = []
wind_speed_list = []

record_counter = 0

print('------------------------')
print('Beginning Weather Check')
print('------------------------')

for city in cities:
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will
    # not have have records in all the cities generated by CityPy module
    try: 
    
        query_url = url + "&q=" + city
        # Get weather data
        response = requests.get(query_url).json()

    #     response = requests.get(query_url + city).json()
        city_list.append(response["name"])
        country_list.append(response["sys"]["country"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        temperature_list.append(response['main']['temp_max'])    
        cloud_list.append(response["clouds"]["all"])
        humidity_list.append(response["main"]["humidity"])

    #    date_list.append(response["dt"])
        wind_speed_list.append(response["wind"]["speed"])
        record_counter += 1
        print('Retrieving data from city of {} ==> Record {}'.format(city, record_counter))
    
#         # If no record found "skip" to next city
    except:
        print('-------------------------')
        print("There are not enough weather information{}. Skip record.")
        print('-------------------------')
        #         print(query_url)


    pass
    
    
    
    
    


print('-------------------------')
print('Finished weather check')
print('-------------------------')
# Out:
# ------------------------
# Beginning Weather Check
# ------------------------
# Retrieving data from city of bjerkvik ==> Record 1
# Retrieving data from city of thompson ==> Record 2
# Retrieving data from city of upernavik ==> Record 3
# Retrieving data from city of hermanus ==> Record 4
# Retrieving data from city of atuona ==> Record 5
# Retrieving data from city of vaini ==> Record 6
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of chumikan ==> Record 7
# Retrieving data from city of sanlucar de barrameda ==> Record 8
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of jamestown ==> Record 9
# Retrieving data from city of georgetown ==> Record 10
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of bredasdorp ==> Record 11
# Retrieving data from city of esperance ==> Record 12
# Retrieving data from city of mareeba ==> Record 13
# Retrieving data from city of lake charles ==> Record 14
# Retrieving data from city of labuhan ==> Record 15
# Retrieving data from city of san patricio ==> Record 16
# Retrieving data from city of albany ==> Record 17
# Retrieving data from city of ribeira grande ==> Record 18
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of nha trang ==> Record 19
# Retrieving data from city of yerbogachen ==> Record 20
# Retrieving data from city of tabas ==> Record 21
# Retrieving data from city of busselton ==> Record 22
# Retrieving data from city of bluff ==> Record 23
# Retrieving data from city of butaritari ==> Record 24
# Retrieving data from city of houston ==> Record 25
# Retrieving data from city of praia ==> Record 26
# Retrieving data from city of qaanaaq ==> Record 27
# Retrieving data from city of banepa ==> Record 28
# Retrieving data from city of kvitok ==> Record 29
# Retrieving data from city of new norfolk ==> Record 30
# Retrieving data from city of rikitea ==> Record 31
# Retrieving data from city of north bend ==> Record 32
# Retrieving data from city of toamasina ==> Record 33
# Retrieving data from city of norman wells ==> Record 34
# Retrieving data from city of praia da vitoria ==> Record 35
# Retrieving data from city of popondetta ==> Record 36
# Retrieving data from city of bambous virieux ==> Record 37
# Retrieving data from city of brigantine ==> Record 38
# Retrieving data from city of kavaratti ==> Record 39
# Retrieving data from city of auki ==> Record 40
# Retrieving data from city of cherskiy ==> Record 41
# Retrieving data from city of sainte-rose ==> Record 42
# Retrieving data from city of zanjan ==> Record 43
# Retrieving data from city of providencia ==> Record 44
# Retrieving data from city of saint-philippe ==> Record 45
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of micheweni ==> Record 46
# Retrieving data from city of guerrero negro ==> Record 47
# Retrieving data from city of carnarvon ==> Record 48
# Retrieving data from city of belmonte ==> Record 49
# Retrieving data from city of hamilton ==> Record 50
# Retrieving data from city of cumberland ==> Record 51
# Retrieving data from city of trelew ==> Record 52
# Retrieving data from city of longyearbyen ==> Record 53
# Retrieving data from city of zhaotong ==> Record 54
# Retrieving data from city of kulhudhuffushi ==> Record 55
# Retrieving data from city of takoradi ==> Record 56
# Retrieving data from city of itarema ==> Record 57
# Retrieving data from city of coquimbo ==> Record 58
# Retrieving data from city of miragoane ==> Record 59
# Retrieving data from city of port alfred ==> Record 60
# Retrieving data from city of te anau ==> Record 61
# Retrieving data from city of sisimiut ==> Record 62
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of lata ==> Record 63
# Retrieving data from city of akyab ==> Record 64
# Retrieving data from city of rio grande ==> Record 65
# Retrieving data from city of hobyo ==> Record 66
# Retrieving data from city of puerto ayora ==> Record 67
# Retrieving data from city of lebu ==> Record 68
# Retrieving data from city of biak ==> Record 69
# Retrieving data from city of ushuaia ==> Record 70
# Retrieving data from city of cartagena ==> Record 71
# Retrieving data from city of dingle ==> Record 72
# Retrieving data from city of kutum ==> Record 73
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of kapaa ==> Record 74
# Retrieving data from city of tuktoyaktuk ==> Record 75
# Retrieving data from city of ozerne ==> Record 76
# Retrieving data from city of bengkulu ==> Record 77
# Retrieving data from city of mehamn ==> Record 78
# Retrieving data from city of mataura ==> Record 79
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of hrob ==> Record 80
# Retrieving data from city of arraial do cabo ==> Record 81
# Retrieving data from city of alushta ==> Record 82
# Retrieving data from city of marsa matruh ==> Record 83
# Retrieving data from city of torbay ==> Record 84
# Retrieving data from city of huarmey ==> Record 85
# Retrieving data from city of mar del plata ==> Record 86
# Retrieving data from city of hilo ==> Record 87
# Retrieving data from city of east london ==> Record 88
# Retrieving data from city of saravan ==> Record 89
# Retrieving data from city of gravelbourg ==> Record 90
# Retrieving data from city of koping ==> Record 91
# Retrieving data from city of menongue ==> Record 92
# Retrieving data from city of hasaki ==> Record 93
# Retrieving data from city of nabire ==> Record 94
# Retrieving data from city of kualakapuas ==> Record 95
# Retrieving data from city of sur ==> Record 96
# Retrieving data from city of lashio ==> Record 97
# Retrieving data from city of ashington ==> Record 98
# Retrieving data from city of saldanha ==> Record 99
# Retrieving data from city of kuala terengganu ==> Record 100
# Retrieving data from city of sembe ==> Record 101
# Retrieving data from city of avarua ==> Record 102
# Retrieving data from city of sao gabriel da cachoeira ==> Record 103
# Retrieving data from city of cockburn town ==> Record 104
# Retrieving data from city of ginir ==> Record 105
# Retrieving data from city of marabba ==> Record 106
# Retrieving data from city of pringsewu ==> Record 107
# Retrieving data from city of belaya gora ==> Record 108
# Retrieving data from city of impfondo ==> Record 109
# Retrieving data from city of kenai ==> Record 110
# Retrieving data from city of carlsbad ==> Record 111
# Retrieving data from city of ondjiva ==> Record 112
# Retrieving data from city of morant bay ==> Record 113
# Retrieving data from city of iralaya ==> Record 114
# Retrieving data from city of thinadhoo ==> Record 115
# Retrieving data from city of katsuura ==> Record 116
# Retrieving data from city of bilma ==> Record 117
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of altamont ==> Record 118
# Retrieving data from city of moree ==> Record 119
# Retrieving data from city of gorzow wielkopolski ==> Record 120
# Retrieving data from city of la rioja ==> Record 121
# Retrieving data from city of tautira ==> Record 122
# Retrieving data from city of frei paulo ==> Record 123
# Retrieving data from city of geraldton ==> Record 124
# Retrieving data from city of alice springs ==> Record 125
# Retrieving data from city of abalak ==> Record 126
# Retrieving data from city of narsaq ==> Record 127
# Retrieving data from city of cape town ==> Record 128
# Retrieving data from city of portland ==> Record 129
# Retrieving data from city of ziro ==> Record 130
# Retrieving data from city of tasiilaq ==> Record 131
# Retrieving data from city of hobart ==> Record 132
# Retrieving data from city of dubbo ==> Record 133
# Retrieving data from city of victor harbor ==> Record 134
# Retrieving data from city of tiksi ==> Record 135
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of punta arenas ==> Record 136
# Retrieving data from city of pevek ==> Record 137
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of riyadh ==> Record 138
# Retrieving data from city of tigre ==> Record 139
# Retrieving data from city of yellowknife ==> Record 140
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of cabo san lucas ==> Record 141
# Retrieving data from city of leningradskiy ==> Record 142
# Retrieving data from city of olafsvik ==> Record 143
# Retrieving data from city of tabuk ==> Record 144
# Retrieving data from city of bilibino ==> Record 145
# Retrieving data from city of buyukcavuslu ==> Record 146
# Retrieving data from city of sioux lookout ==> Record 147
# Retrieving data from city of ascension ==> Record 148
# Retrieving data from city of fort frances ==> Record 149
# Retrieving data from city of simao ==> Record 150
# Retrieving data from city of mount isa ==> Record 151
# Retrieving data from city of nikolskoye ==> Record 152
# Retrieving data from city of ibra ==> Record 153
# Retrieving data from city of abonnema ==> Record 154
# Retrieving data from city of khatanga ==> Record 155
# Retrieving data from city of san quintin ==> Record 156
# Retrieving data from city of ujjain ==> Record 157
# Retrieving data from city of barrow ==> Record 158
# Retrieving data from city of baniyas ==> Record 159
# Retrieving data from city of touros ==> Record 160
# Retrieving data from city of cuamba ==> Record 161
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of huangchuan ==> Record 162
# Retrieving data from city of beringovskiy ==> Record 163
# Retrieving data from city of cabinda ==> Record 164
# Retrieving data from city of provideniya ==> Record 165
# Retrieving data from city of zhuhai ==> Record 166
# Retrieving data from city of vilhena ==> Record 167
# Retrieving data from city of shingu ==> Record 168
# Retrieving data from city of ponta do sol ==> Record 169
# Retrieving data from city of kayes ==> Record 170
# Retrieving data from city of bethel ==> Record 171
# Retrieving data from city of andenes ==> Record 172
# Retrieving data from city of klaksvik ==> Record 173
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of boffa ==> Record 174
# Retrieving data from city of kinango ==> Record 175
# Retrieving data from city of hamada ==> Record 176
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of taoudenni ==> Record 177
# Retrieving data from city of tazmalt ==> Record 178
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of wanning ==> Record 179
# Retrieving data from city of soligalich ==> Record 180
# Retrieving data from city of cholet ==> Record 181
# Retrieving data from city of juneau ==> Record 182
# Retrieving data from city of baykit ==> Record 183
# Retrieving data from city of nanortalik ==> Record 184
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of dikson ==> Record 185
# Retrieving data from city of huaihua ==> Record 186
# Retrieving data from city of tabou ==> Record 187
# Retrieving data from city of karratha ==> Record 188
# Retrieving data from city of kaitangata ==> Record 189
# Retrieving data from city of avera ==> Record 190
# Retrieving data from city of souillac ==> Record 191
# Retrieving data from city of mashhad ==> Record 192
# Retrieving data from city of balakhninskiy ==> Record 193
# Retrieving data from city of payo ==> Record 194
# Retrieving data from city of shawnee ==> Record 195
# Retrieving data from city of mujiayingzi ==> Record 196
# Retrieving data from city of padang ==> Record 197
# Retrieving data from city of ambilobe ==> Record 198
# Retrieving data from city of ustye ==> Record 199
# Retrieving data from city of seoul ==> Record 200
# Retrieving data from city of okhotsk ==> Record 201
# Retrieving data from city of la ceiba ==> Record 202
# Retrieving data from city of meulaboh ==> Record 203
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of sola ==> Record 204
# Retrieving data from city of gravdal ==> Record 205
# Retrieving data from city of saint george ==> Record 206
# Retrieving data from city of san blas ==> Record 207
# Retrieving data from city of lalibela ==> Record 208
# Retrieving data from city of zeerust ==> Record 209
# Retrieving data from city of sehithwa ==> Record 210
# Retrieving data from city of petropavlovsk-kamchatskiy ==> Record 211
# Retrieving data from city of henties bay ==> Record 212
# Retrieving data from city of camana ==> Record 213
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of zafarwal ==> Record 214
# Retrieving data from city of naron ==> Record 215
# Retrieving data from city of kanniyakumari ==> Record 216
# Retrieving data from city of coahuayana ==> Record 217
# Retrieving data from city of altay ==> Record 218
# Retrieving data from city of chabahar ==> Record 219
# Retrieving data from city of nyurba ==> Record 220
# Retrieving data from city of zonguldak ==> Record 221
# Retrieving data from city of guiratinga ==> Record 222
# Retrieving data from city of aswan ==> Record 223
# Retrieving data from city of suntar ==> Record 224
# Retrieving data from city of arkhara ==> Record 225
# Retrieving data from city of victoria ==> Record 226
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of chuy ==> Record 227
# Retrieving data from city of opuwo ==> Record 228
# Retrieving data from city of san benito ==> Record 229
# Retrieving data from city of mitsamiouli ==> Record 230
# Retrieving data from city of iqaluit ==> Record 231
# Retrieving data from city of pangai ==> Record 232
# Retrieving data from city of berezovyy ==> Record 233
# Retrieving data from city of port-gentil ==> Record 234
# Retrieving data from city of severo-kurilsk ==> Record 235
# Retrieving data from city of kavieng ==> Record 236
# Retrieving data from city of xilagani ==> Record 237
# Retrieving data from city of reni ==> Record 238
# Retrieving data from city of guerrero ==> Record 239
# Retrieving data from city of ritchie ==> Record 240
# Retrieving data from city of norwalk ==> Record 241
# Retrieving data from city of kaeo ==> Record 242
# Retrieving data from city of deputatskiy ==> Record 243
# Retrieving data from city of kuusamo ==> Record 244
# Retrieving data from city of aitape ==> Record 245
# Retrieving data from city of wyndham ==> Record 246
# Retrieving data from city of mokhsogollokh ==> Record 247
# Retrieving data from city of sistranda ==> Record 248
# Retrieving data from city of castro ==> Record 249
# Retrieving data from city of husavik ==> Record 250
# Retrieving data from city of hualmay ==> Record 251
# Retrieving data from city of port elizabeth ==> Record 252
# Retrieving data from city of kintampo ==> Record 253
# Retrieving data from city of pangnirtung ==> Record 254
# Retrieving data from city of sorata ==> Record 255
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of la ronge ==> Record 256
# Retrieving data from city of komsomolskiy ==> Record 257
# Retrieving data from city of manzhouli ==> Record 258
# Retrieving data from city of suba ==> Record 259
# Retrieving data from city of salalah ==> Record 260
# Retrieving data from city of rocha ==> Record 261
# Retrieving data from city of porosozero ==> Record 262
# Retrieving data from city of bathsheba ==> Record 263
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of vostok ==> Record 264
# Retrieving data from city of monopoli ==> Record 265
# Retrieving data from city of dawlatabad ==> Record 266
# Retrieving data from city of chilmari ==> Record 267
# Retrieving data from city of znamenskoye ==> Record 268
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of zambezi ==> Record 269
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of ixtapa ==> Record 270
# Retrieving data from city of salinas ==> Record 271
# Retrieving data from city of airai ==> Record 272
# Retrieving data from city of isangel ==> Record 273
# Retrieving data from city of upington ==> Record 274
# Retrieving data from city of kahului ==> Record 275
# Retrieving data from city of laguna ==> Record 276
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of jaen ==> Record 277
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of kieta ==> Record 278
# Retrieving data from city of mulanje ==> Record 279
# Retrieving data from city of sao filipe ==> Record 280
# Retrieving data from city of saint-pierre ==> Record 281
# Retrieving data from city of penne ==> Record 282
# Retrieving data from city of whitecourt ==> Record 283
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of kabinda ==> Record 284
# Retrieving data from city of kibala ==> Record 285
# Retrieving data from city of westport ==> Record 286
# Retrieving data from city of burns lake ==> Record 287
# Retrieving data from city of poum ==> Record 288
# Retrieving data from city of dukat ==> Record 289
# Retrieving data from city of luderitz ==> Record 290
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of alta floresta ==> Record 291
# Retrieving data from city of yulara ==> Record 292
# Retrieving data from city of hammerfest ==> Record 293
# Retrieving data from city of pisco ==> Record 294
# Retrieving data from city of farafangana ==> Record 295
# Retrieving data from city of nouadhibou ==> Record 296
# Retrieving data from city of sinnamary ==> Record 297
# Retrieving data from city of gabu ==> Record 298
# Retrieving data from city of san carlos de bariloche ==> Record 299
# Retrieving data from city of maceio ==> Record 300
# Retrieving data from city of saskylakh ==> Record 301
# Retrieving data from city of mount gambier ==> Record 302
# Retrieving data from city of quelimane ==> Record 303
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of srednekolymsk ==> Record 304
# Retrieving data from city of ancud ==> Record 305
# Retrieving data from city of yangjiang ==> Record 306
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of nelson bay ==> Record 307
# Retrieving data from city of gorin ==> Record 308
# Retrieving data from city of chokurdakh ==> Record 309
# Retrieving data from city of holme ==> Record 310
# Retrieving data from city of ouahigouya ==> Record 311
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of broome ==> Record 312
# Retrieving data from city of yaan ==> Record 313
# Retrieving data from city of paamiut ==> Record 314
# Retrieving data from city of kailua ==> Record 315
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of warri ==> Record 316
# Retrieving data from city of timra ==> Record 317
# Retrieving data from city of shimoda ==> Record 318
# Retrieving data from city of fayaoue ==> Record 319
# Retrieving data from city of vestmannaeyjar ==> Record 320
# Retrieving data from city of jieshi ==> Record 321
# Retrieving data from city of luba ==> Record 322
# Retrieving data from city of ilulissat ==> Record 323
# Retrieving data from city of birobidzhan ==> Record 324
# Retrieving data from city of sinop ==> Record 325
# Retrieving data from city of sarrebourg ==> Record 326
# Retrieving data from city of codrington ==> Record 327
# Retrieving data from city of izumo ==> Record 328
# Retrieving data from city of otradnoye ==> Record 329
# Retrieving data from city of san isidro ==> Record 330
# Retrieving data from city of jalu ==> Record 331
# Retrieving data from city of tiznit ==> Record 332
# Retrieving data from city of mehran ==> Record 333
# Retrieving data from city of sibu ==> Record 334
# Retrieving data from city of halifax ==> Record 335
# Retrieving data from city of surt ==> Record 336
# Retrieving data from city of kupang ==> Record 337
# Retrieving data from city of sao joao da barra ==> Record 338
# Retrieving data from city of vieste ==> Record 339
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of camacha ==> Record 340
# Retrieving data from city of plettenberg bay ==> Record 341
# Retrieving data from city of pudozh ==> Record 342
# Retrieving data from city of port-cartier ==> Record 343
# Retrieving data from city of palmer ==> Record 344
# Retrieving data from city of vila do maio ==> Record 345
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of tuatapere ==> Record 346
# Retrieving data from city of paita ==> Record 347
# Retrieving data from city of fort nelson ==> Record 348
# Retrieving data from city of sapa ==> Record 349
# Retrieving data from city of alekseyevsk ==> Record 350
# Retrieving data from city of malayal ==> Record 351
# Retrieving data from city of constitucion ==> Record 352
# Retrieving data from city of point pedro ==> Record 353
# Retrieving data from city of kolochava ==> Record 354
# Retrieving data from city of amroha ==> Record 355
# Retrieving data from city of salinopolis ==> Record 356
# Retrieving data from city of bani walid ==> Record 357
# Retrieving data from city of xuddur ==> Record 358
# Retrieving data from city of hatfield ==> Record 359
# Retrieving data from city of prokuplje ==> Record 360
# Retrieving data from city of kruisfontein ==> Record 361
# Retrieving data from city of beyneu ==> Record 362
# Retrieving data from city of esil ==> Record 363
# Retrieving data from city of kashi ==> Record 364
# Retrieving data from city of saint anthony ==> Record 365
# Retrieving data from city of riverton ==> Record 366
# Retrieving data from city of baghdad ==> Record 367
# Retrieving data from city of marawi ==> Record 368
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of haines junction ==> Record 369
# Retrieving data from city of yakeshi ==> Record 370
# Retrieving data from city of hondo ==> Record 371
# Retrieving data from city of billings ==> Record 372
# Retrieving data from city of hovd ==> Record 373
# Retrieving data from city of raudeberg ==> Record 374
# Retrieving data from city of sorland ==> Record 375
# Retrieving data from city of mmabatho ==> Record 376
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of tambacounda ==> Record 377
# Retrieving data from city of iquitos ==> Record 378
# Retrieving data from city of chernyshevskiy ==> Record 379
# Retrieving data from city of lagunillas ==> Record 380
# Retrieving data from city of traipu ==> Record 381
# Retrieving data from city of khorixas ==> Record 382
# Retrieving data from city of hithadhoo ==> Record 383
# Retrieving data from city of okha ==> Record 384
# Retrieving data from city of verkh-usugli ==> Record 385
# Retrieving data from city of luanda ==> Record 386
# Retrieving data from city of bayir ==> Record 387
# Retrieving data from city of okoneshnikovo ==> Record 388
# Retrieving data from city of clyde river ==> Record 389
# Retrieving data from city of crotone ==> Record 390
# Retrieving data from city of araceli ==> Record 391
# Retrieving data from city of hit ==> Record 392
# Retrieving data from city of kloulklubed ==> Record 393
# Retrieving data from city of ouegoa ==> Record 394
# Retrieving data from city of podsineye ==> Record 395
# Retrieving data from city of yar-sale ==> Record 396
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of soria ==> Record 397
# Retrieving data from city of domazlice ==> Record 398
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of puerto madryn ==> Record 399
# Retrieving data from city of mogadishu ==> Record 400
# Retrieving data from city of jardim ==> Record 401
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of fortuna ==> Record 402
# Retrieving data from city of faya ==> Record 403
# Retrieving data from city of najran ==> Record 404
# Retrieving data from city of faanui ==> Record 405
# Retrieving data from city of singaraja ==> Record 406
# Retrieving data from city of cavalcante ==> Record 407
# Retrieving data from city of lebedinyy ==> Record 408
# Retrieving data from city of college ==> Record 409
# Retrieving data from city of tadine ==> Record 410
# Retrieving data from city of alofi ==> Record 411
# Retrieving data from city of san cristobal ==> Record 412
# Retrieving data from city of asau ==> Record 413
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of ipixuna ==> Record 414
# Retrieving data from city of ballina ==> Record 415
# Retrieving data from city of kawalu ==> Record 416
# Retrieving data from city of nakamura ==> Record 417
# Retrieving data from city of lorengau ==> Record 418
# Retrieving data from city of kumluca ==> Record 419
# Retrieving data from city of kirsanov ==> Record 420
# Retrieving data from city of boulder city ==> Record 421
# Retrieving data from city of jiaonan ==> Record 422
# Retrieving data from city of kalinovskoye ==> Record 423
# Retrieving data from city of richards bay ==> Record 424
# Retrieving data from city of vanimo ==> Record 425
# Retrieving data from city of hami ==> Record 426
# Retrieving data from city of antalaha ==> Record 427
# Retrieving data from city of aginskoye ==> Record 428
# Retrieving data from city of aranos ==> Record 429
# Retrieving data from city of looc ==> Record 430
# Retrieving data from city of mathathane ==> Record 431
# Retrieving data from city of ramygala ==> Record 432
# Retrieving data from city of karatau ==> Record 433
# Retrieving data from city of mahon ==> Record 434
# Retrieving data from city of kodinsk ==> Record 435
# Retrieving data from city of tessalit ==> Record 436
# Retrieving data from city of fairbanks ==> Record 437
# Retrieving data from city of kyabe ==> Record 438
# Retrieving data from city of mahebourg ==> Record 439
# Retrieving data from city of dunedin ==> Record 440
# Retrieving data from city of eagle pass ==> Record 441
# Retrieving data from city of mocuba ==> Record 442
# Retrieving data from city of boguchany ==> Record 443
# Retrieving data from city of la spezia ==> Record 444
# Retrieving data from city of nicoya ==> Record 445
# Retrieving data from city of williams lake ==> Record 446
# Retrieving data from city of houma ==> Record 447
# Retrieving data from city of pimenta bueno ==> Record 448
# Retrieving data from city of lagoa ==> Record 449
# Retrieving data from city of suleja ==> Record 450
# Retrieving data from city of verkhnyaya sinyachikha ==> Record 451
# Retrieving data from city of oskarshamn ==> Record 452
# Retrieving data from city of carbonia ==> Record 453
# Retrieving data from city of marzuq ==> Record 454
# Retrieving data from city of la asuncion ==> Record 455
# Retrieving data from city of roma ==> Record 456
# Retrieving data from city of santiago ==> Record 457
# Retrieving data from city of elko ==> Record 458
# Retrieving data from city of bisho ==> Record 459
# Retrieving data from city of broken hill ==> Record 460
# Retrieving data from city of verkhoyansk ==> Record 461
# Retrieving data from city of jerusalem ==> Record 462
# Retrieving data from city of alghero ==> Record 463
# Retrieving data from city of maldonado ==> Record 464
# Retrieving data from city of mae sai ==> Record 465
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of lokosovo ==> Record 466
# Retrieving data from city of vangaindrano ==> Record 467
# Retrieving data from city of nchelenge ==> Record 468
# Retrieving data from city of marrakesh ==> Record 469
# Retrieving data from city of otjimbingwe ==> Record 470
# Retrieving data from city of luganville ==> Record 471
# Retrieving data from city of tolaga bay ==> Record 472
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of veraval ==> Record 473
# Retrieving data from city of buraydah ==> Record 474
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of lakes entrance ==> Record 475
# Retrieving data from city of wangkui ==> Record 476
# Retrieving data from city of mutis ==> Record 477
# Retrieving data from city of caravelas ==> Record 478
# Retrieving data from city of lodja ==> Record 479
# Retrieving data from city of raton ==> Record 480
# Retrieving data from city of kesinga ==> Record 481
# Retrieving data from city of adrar ==> Record 482
# Retrieving data from city of lompoc ==> Record 483
# Retrieving data from city of nirgua ==> Record 484
# Retrieving data from city of idrinskoye ==> Record 485
# Retrieving data from city of paignton ==> Record 486
# Retrieving data from city of vardo ==> Record 487
# Retrieving data from city of margate ==> Record 488
# Retrieving data from city of san vicente ==> Record 489
# Retrieving data from city of honiara ==> Record 490
# Retrieving data from city of dawei ==> Record 491
# Retrieving data from city of port augusta ==> Record 492
# Retrieving data from city of mbanza-ngungu ==> Record 493
# Retrieving data from city of agapovka ==> Record 494
# Retrieving data from city of puerto del rosario ==> Record 495
# Retrieving data from city of nador ==> Record 496
# Retrieving data from city of grand-santi ==> Record 497
# Retrieving data from city of harper ==> Record 498
# Retrieving data from city of evensk ==> Record 499
# Retrieving data from city of san miguel de cauri ==> Record 500
# Retrieving data from city of cururupu ==> Record 501
# Retrieving data from city of san policarpo ==> Record 502
# Retrieving data from city of mpanda ==> Record 503
# Retrieving data from city of shirokiy ==> Record 504
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of bandarbeyla ==> Record 505
# Retrieving data from city of vao ==> Record 506
# Retrieving data from city of santa rosa ==> Record 507
# Retrieving data from city of carangola ==> Record 508
# Retrieving data from city of aleksandrov gay ==> Record 509
# Retrieving data from city of cody ==> Record 510
# Retrieving data from city of verkhnevilyuysk ==> Record 511
# Retrieving data from city of muisne ==> Record 512
# Retrieving data from city of san juan ==> Record 513
# Retrieving data from city of chardara ==> Record 514
# Retrieving data from city of rundu ==> Record 515
# Retrieving data from city of formosa do rio preto ==> Record 516
# Retrieving data from city of kodiak ==> Record 517
# Retrieving data from city of aksha ==> Record 518
# Retrieving data from city of novikovo ==> Record 519
# Retrieving data from city of ahipara ==> Record 520
# Retrieving data from city of cayenne ==> Record 521
# Retrieving data from city of brokopondo ==> Record 522
# Retrieving data from city of azoyu ==> Record 523
# Retrieving data from city of sitka ==> Record 524
# Retrieving data from city of moctezuma ==> Record 525
# Retrieving data from city of vacha ==> Record 526
# Retrieving data from city of masuda ==> Record 527
# -------------------------
# There are not enough weather information{}. Skip record.
# -------------------------
# Retrieving data from city of nuevo progreso ==> Record 528
# Retrieving data from city of lasa ==> Record 529
# Retrieving data from city of ormara ==> Record 530
# Retrieving data from city of gizo ==> Record 531
# -------------------------
# Finished weather check
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# move data to dictionary and the DF
weather_data_dict = {
    "City": city_list,
    "Lat":lat_list, 
    "Lng":lng_list, 
    "Country":country_list,
    "Max.Temp": temperature_list,    
    "Humidity": humidity_list,   
    "Cloudiness":cloud_list, 
    "Wind Speed":wind_speed_list
}

# Create a data frame from dictionary
weather_data_df = pd.DataFrame(weather_data_dict)

# Display count of weather data values 
# weather_data_df.count()
weather_data_df
# Out:
#                         City      Lat       Lng Country  Max.Temp  Humidity  \
# 0                   Bjerkvik  68.5597   17.5189      NO      4.00        75
# 1                   Thompson  55.7435  -97.8558      CA     12.00        35
# 2                  Upernavik  72.7868  -56.1549      GL    -13.27        88
# 3                   Hermanus -34.4187   19.2345      ZA     17.78        85
# 4                     Atuona  -9.8000 -139.0333      PF     26.72        75
# ..                       ...      ...       ...     ...       ...       ...
# 526                   Masuda  34.6667  131.8500      JP     13.33        71
# 527           Nuevo Progreso  23.1667  -97.9500      MX     21.67        55
# 528                     Laas  46.6166   10.7002      IT      4.00        63
# 529                   Ormara  25.2088   64.6357      PK     23.31        74
# 530  Gizo Government Station  -8.1030  156.8419      SB     29.16        67
#
#      Cloudiness  Wind Speed
# 0            90        2.57
# 1            75        3.60
# 2           100        2.04
# 3           100        5.45
# 4            25        5.54
# ..          ...         ...
# 526          75        1.54
# 527           2        4.02
# 528          20        1.54
# 529           2        1.69
# 530           2        1.32
#
# [531 rows x 8 columns]

# %%
# Save data frame to CSV
# i have anticipated step
weather_data_df.to_csv('weather_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# humid_100_df = weather_data_df.loc[reduced_df["Drug Regimen"] == 100,:]

humid_100_df = weather_data_df.loc[weather_data_df["Humidity"] == 100,:]

humid_100_df
# Out:
#             City      Lat       Lng Country  Max.Temp  Humidity  Cloudiness  \
# 83        Torbay  47.6666  -52.7314      CA      6.67       100          90
# 94   Kualakapuas  -3.0091  114.3876      ID     23.00       100          40
# 172     Klaksvík  62.2266   -6.5890      FO      7.00       100          75
# 196       Padang  -0.9492  100.3543      ID     24.00       100          75
# 306   Nelson Bay -32.7167  152.1500      AU     20.56       100          90
# 336       Kupang -10.1667  123.5833      ID     25.00       100          75
# 389      Crotone  39.0851   17.1178      IT      6.11       100          90
# 396        Soria  41.6667   -2.6667      ES      0.00       100           6
# 493     Agapovka  53.2973   59.1348      RU     -4.00       100          90
#
#      Wind Speed
# 83        21.09
# 94         2.57
# 172        8.75
# 196        1.03
# 306        4.12
# 336        1.03
# 389        4.12
# 396        4.34
# 493        4.00

# %%
#  Get the indices of cities that have humidity over 100%.
humid_100_df.index
# Out:
# Int64Index([83, 94, 172, 196, 306, 336, 389, 396, 493], dtype='int64')

# %%
# # Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# # Passing "inplace=False" will make a copy of the city_data DataFrame, which we call 
# # "clean_city_data".

# # clean_city_data_df = weather_data_df.drop(weather_data_df["Humidity"] == 100.index, inplace=False)
# # clean_city_data_df = weather_data_df.loc(weather_data_df["Humidity"] == 100, inplace=False)
clean_city_data_df = weather_data_df.loc[weather_data_df["Humidity"] < 100]


# #  clean_city_data_df =df.drop(df[df.score < 50].index, inplace=True)
clean_city_data_df
# Out:
#                         City      Lat       Lng Country  Max.Temp  Humidity  \
# 0                   Bjerkvik  68.5597   17.5189      NO      4.00        75
# 1                   Thompson  55.7435  -97.8558      CA     12.00        35
# 2                  Upernavik  72.7868  -56.1549      GL    -13.27        88
# 3                   Hermanus -34.4187   19.2345      ZA     17.78        85
# 4                     Atuona  -9.8000 -139.0333      PF     26.72        75
# ..                       ...      ...       ...     ...       ...       ...
# 526                   Masuda  34.6667  131.8500      JP     13.33        71
# 527           Nuevo Progreso  23.1667  -97.9500      MX     21.67        55
# 528                     Laas  46.6166   10.7002      IT      4.00        63
# 529                   Ormara  25.2088   64.6357      PK     23.31        74
# 530  Gizo Government Station  -8.1030  156.8419      SB     29.16        67
#
#      Cloudiness  Wind Speed
# 0            90        2.57
# 1            75        3.60
# 2           100        2.04
# 3           100        5.45
# 4            25        5.54
# ..          ...         ...
# 526          75        1.54
# 527           2        4.02
# 528          20        1.54
# 529           2        1.69
# 530           2        1.32
#
# [522 rows x 8 columns]

# %%
# Save data frame to CSV

clean_city_data_df.to_csv('clean_city_data_df.csv')

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# clean_city_data_df.columns

# %%
                                    
plt.figure(figsize=(12, 5))    # Set up total size of graph
    
    
# Plot scatter
plt.scatter(clean_city_data_df["Lat"], 
            clean_city_data_df["Max.Temp"], 
            marker="o", 
            s=40, 
            color="yellow",
            edgecolors='black')


# Incorporate the other graph properties
plt.title("City Latitude vs. Max.Temperature")
plt.ylabel("Max. Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("figures/Latitude_vs_Temp.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(12, 5))    # Set up total size of graph

# Scatter plot
plt.scatter(weather_data_df["Lat"], 
            weather_data_df["Humidity"], 
            marker="o", 
            s=40, 
            color="yellow",
            edgecolors='black')

# Rest of graph details
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("figures/Latitude_vs_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# plot
plt.figure(figsize=(12, 5))    # Set up total size of graph

# Scatter plot
plt.scatter(weather_data_df["Lat"], 
            weather_data_df["Cloudiness"], 
            marker="o", 
            s=40, 
            color="yellow",
            edgecolors='black')


# Rest of graph details
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("figures/Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(12, 5))    # Set up total size of graph

# Scatter plot
plt.scatter(weather_data_df["Lat"], 
            weather_data_df["Wind Speed"], 
            marker="o", 
            s=40, 
            color="yellow",
            edgecolors='black')



# Rest of graph details
plt.title("City Latitude vs. Wind Speed(kpm)")
plt.ylabel("Temperature (C)")
plt.xlabel("Wind Speed (kph)")
plt.grid(True)

# Save the figure
plt.savefig("figures/Latitude_vs_Wind.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
north_lat = weather_data_df.loc[weather_data_df["Lat"] >= 0]
south_lat = weather_data_df.loc[weather_data_df["Lat"] < 0]

# north_lat

# %%
#---------------------------------

# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_lat["Max.Temp"], north_lat["Lat"])
regress_values = north_lat["Max.Temp"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(north_lat["Max.Temp"],north_lat["Lat"])                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In northern hemisphere he correlation coeficient between Max.Temperature and Latitude is {correlation}")

plt.figure(figsize=(14, 8))                                        # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(north_lat["Max.Temp"], north_lat["Lat"],
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(north_lat["Max.Temp"],regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(-25,79),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
plt.title("Northern Hemisphere - Linear regression of Max Temp. vs Latitude",fontsize =18)
plt.xlabel("Max. Temperature (C)",fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(0, 90, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Northern_Regression_Max_temp_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In northern hemisphere he correlation coeficient between Max.Temperature and Latitude is -0.88

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# variables:

x = south_lat["Max.Temp"]
y = south_lat["Lat"]


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In southern hemisphere he correlation coeficient between Max.Temperature and Latitude is {correlation}")





plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(10,-30),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title("Southern Hemisphere - Linear regression of Max Temp. vs Latitude",fontsize =18)
plt.xlabel("Max. Temperature (C)",fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(-90, 0, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Southern_Regression_Max_Temp_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In southern hemisphere he correlation coeficient between Max.Temperature and Latitude is 0.63

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# variables:

x = north_lat["Humidity"]
y = north_lat["Lat"]
text_x = "Humidity %"
where = "Northern Hemisphere"


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In {where} he correlation coeficient between {text_x} and Latitude is {correlation}")

plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(43,40),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title(f"{where} - Linear regression of {text_x}. vs Latitude",fontsize =18)
plt.xlabel(text_x,fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(0, 90, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Northern_Regression_Humidity_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In Northern Hemisphere he correlation coeficient between Humidity % and Latitude is 0.19

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# variables:

x = south_lat["Humidity"]
y = south_lat["Lat"]
text_x = "Humidity %"
where = "Southern Hemisphere"


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In {where} he correlation coeficient between {text_x} and Latitude is {correlation}")

plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(30,-39),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title(f"{where} - Linear regression of {text_x}. vs Latitude",fontsize =18)
plt.xlabel(text_x,fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(-90, 0, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Southern_Regression_Humidity_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In Southern Hemisphere he correlation coeficient between Humidity % and Latitude is 0.36

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# variables:

x = north_lat["Cloudiness"]
y = north_lat["Lat"]
text_x = "Cloudiness"
where = "Northern Hemisphere"


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In {where} he correlation coeficient between {text_x} and Latitude is {correlation}")

plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(23,40),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title(f"{where} - Linear regression of {text_x}. vs Latitude",fontsize =18)
plt.xlabel(text_x,fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(0, 90, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Northern_Regression_Cloudiness_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In Northern Hemisphere he correlation coeficient between Cloudiness and Latitude is 0.29

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# variables:

x = south_lat["Cloudiness"]
y = south_lat["Lat"]
text_x = "Cloudiness %"
where = "Southern Hemisphere"


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In {where} he correlation coeficient between {text_x} and Latitude is {correlation}")

plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(50,-18),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title(f"{where} - Linear regression of {text_x}. vs Latitude",fontsize =18)
plt.xlabel(text_x,fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(-90, 0, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Southern_Regression_Cloudiness_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In Southern Hemisphere he correlation coeficient between Cloudiness % and Latitude is 0.17

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x = north_lat["Wind Speed"]
y = north_lat["Lat"]
text_x = "Wind Speed (kph)"
where = "Northern Hemisphere"


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In {where} he correlation coeficient between {text_x} and Latitude is {correlation}")

plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(11,55),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title(f"{where} - Linear regression of {text_x}. vs Latitude",fontsize =18)
plt.xlabel(text_x,fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(0, 90, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Northern_Regression_Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In Northern Hemisphere he correlation coeficient between Wind Speed (kph) and Latitude is 0.19

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# variables:

x = south_lat["Wind Speed"]
y = south_lat["Lat"]
text_x = "Wind Speed (kph)"
where = "Southern Hemisphere"


# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(x,y)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"In {where} he correlation coeficient between {text_x} and Latitude is {correlation}")

plt.figure(figsize=(14, 8))     # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(x, y,
            s=40, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(x,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(12,-35),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
 
plt.title(f"{where} - Linear regression of {text_x}. vs Latitude",fontsize =18)
plt.xlabel(text_x,fontsize =16)
plt.ylabel("Latitude",fontsize =16)
plt.xticks(fontsize=13)
plt.yticks(np.arange(-90, 0, 10.0))  
plt.yticks(fontsize=13)
plt.grid()

# Save the figure
plt.savefig("figures/Southern_Regression_Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
# Out:
# In Southern Hemisphere he correlation coeficient between Wind Speed (kph) and Latitude is -0.36
