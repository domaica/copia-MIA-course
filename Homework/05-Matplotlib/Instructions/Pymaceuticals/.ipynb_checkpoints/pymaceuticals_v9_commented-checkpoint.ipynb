# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset keeping every value in all raws
mouse_dataset_df = pd.merge(mouse_metadata, study_results, how = "outer", on='Mouse ID' )


# Display the data table for preview
mouse_dataset_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice. Count number of unique entries in field "Mouse ID"
num_of_mice = mouse_dataset_df['Mouse ID'].nunique()
num_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_rows_df = mouse_dataset_df[mouse_dataset_df.duplicated(['Mouse ID', 'Timepoint'])]
# print("Duplicate Rows based on 2 columns are:", duplicate_rows_df, sep='\n')
print("Duplicate Rows based on 2 columns are:")
duplicate_rows_df
# Out:
# Duplicate Rows based on 2 columns are:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.
# According to parameter documentation, Using keep=False means that both every duplicated row is displayed
duplicate_rows_df = mouse_dataset_df[mouse_dataset_df.duplicated(['Mouse ID', 'Timepoint'], keep=False)]
duplicate_rows_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = mouse_dataset_df.loc[mouse_dataset_df["Mouse ID"] != "g989"]
clean_df

# ADDITIONAL TESTED METHOD clean_df = mouse_dataset_df.drop_duplicates(keep=False)
# clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame. Mouse ID = g989 has dropped so there is one less mouse
num_of_mice_clean_df = clean_df['Mouse ID'].nunique()
num_of_mice_clean_df
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties 
# of each drug regimen: 
summary_stats_df = clean_df.groupby('Drug Regimen')
# summary_stats_df.head()

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
tumor_vol_mean = summary_stats_df['Tumor Volume (mm3)'].mean()      # calculate average of tumor volume column
tumor_vol_median = summary_stats_df['Tumor Volume (mm3)'].median()  # calculate median of tumor volume column
tumor_vol_stdev = summary_stats_df['Tumor Volume (mm3)'].std()      # calculate standard deviation of tumor volume column
tumor_vol_sem = summary_stats_df['Tumor Volume (mm3)'].sem()        # calculate standard error of the mean (SEM)
                                                                    # of tumor volume column

# Assemble the resulting series into a single summary dataframe.
summary_groupby_df = pd.DataFrame({'Mean': tumor_vol_mean, 'Median': tumor_vol_median,
                                   'Std Deviation': tumor_vol_stdev, 'SEM': tumor_vol_sem})

summary_groupby_df
# Out:
#                    Mean     Median  Std Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809       4.994774  0.329346
# Ceftamin      52.591172  51.776157       6.268188  0.469821
# Infubinol     52.884795  51.820584       6.567243  0.492236
# Ketapril      55.235638  53.698743       8.279709  0.603860
# Naftisol      54.331565  52.509285       8.134708  0.596466
# Placebo       54.033581  52.288934       7.821003  0.581331
# Propriva      52.320930  50.446266       6.622085  0.544332
# Ramicane      40.216745  40.673236       4.846308  0.320955
# Stelasyn      54.233149  52.431737       7.710419  0.573111
# Zoniferol     53.236507  51.818479       6.966589  0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line
# THIS REQUEST IS KIND OF STRANGE AND PRODUCE STRANGE RESULTS, SEE BELOW EXPLANATION

# Aggregate every mean result for every drug and calculate mean of them
total_tumor_vol_mean = summary_groupby_df['Mean'].mean()
# Aggregate every median result for every drug and calculate median of this subset of results of previous table
total_tumor_vol_median = summary_groupby_df['Median'].median()

# in this result, I calculate the average of previous table standard deviations, because if I calculate the standard
# deviation of the standard deviations in the table, the result is 1.216, what is meaningless for std of population
# On the other hand, calculating average of STDs of table, result is 6.821, a more useful and meaningful value
total_tumor_vol_std = summary_groupby_df['Std Deviation'].mean()
# total_tumor_vol_std = summary_groupby_df['Std Deviation'].std()

# in this result, I calculate the average of previous table Standard Error of Means, because if I calculate the SEM
# of the SEMs subset in the table, the result is 0.033, what is meaningless for SEM of total population data
# On the other hand, calculating average of SEMs of table, result is 0.503, a more useful and meaningful value
total_tumor_vol_sem = summary_groupby_df['SEM'].mean()
# total_tumor_vol_sem = summary_groupby_df['SEM'].sem()

total_tumor_vol_mean = round(total_tumor_vol_mean, 3)
total_tumor_vol_median = round(total_tumor_vol_median, 3)
total_tumor_vol_std = round(total_tumor_vol_std, 3)
total_tumor_vol_sem = round(total_tumor_vol_sem, 3)

arr = np.array(['Mean:',total_tumor_vol_mean, '    ', 'Median:',total_tumor_vol_median, 
               '    ',  'Std Deviation:',total_tumor_vol_std,'    ', 'SEM:', total_tumor_vol_sem])
print(*arr, sep = ' ')
# Out:
# Mean: 50.976      Median: 51.82      Std Deviation: 6.821      SEM: 0.503

# %% [markdown]
# ## Bar and Pie Charts

# %%
# summary_stats_df.head()

# %%
# Generate a bar plot showing the total number of measurements taken 
# on each drug regimen using PANDAS.

# We already have calculated 'summary_stats_df' which was clean and groupedby "Drug Regimen". It also contained needed
# 'Timepoints' column. We reuse it
num_of_meas_by_drug = pd.DataFrame(summary_stats_df.count()["Timepoint"])

# setup graph using pandas and required parameter for BAR graph
plot_with_pandas = num_of_meas_by_drug.plot(kind='bar', 
                                            width=0.55, 
                                            figsize=(12,6), 
                                            color='r',
                                            fontsize = 12, 
                                            legend=False)

# Set labels for axes
plot_with_pandas.set_xlabel("Drug Regimen",fontsize = 16, color='b')
plot_with_pandas.set_ylabel("Number of Data Points",fontsize = 16, color='b')
# Set title
plot_with_pandas.set_title("Number of Data Points for Each Treatment Regimen",fontsize = 18)

# # plt.tight_layout()
plt.show()

# %%
# num_of_meas_by_drug.columns

# %%
# Generate a bar plot showing the total number of measurements taken 
# on each drug regimen using PYPLOT.

# Using previous groupby dataframe already obtained
num_of_meas_by_drug = summary_stats_df.count()["Timepoint"]

# Set x axis and tick locations calculating lenght or number of dataframe rows
x_axis = np.arange(len(num_of_meas_by_drug))
# loop including them in x axis
tick_locations = [value for value in x_axis]

# BEFORE set figure size to adjust for space
plt.figure(figsize=(12,6))
           
# thickness = width. Trying to match above graph
plt.bar(x_axis, num_of_meas_by_drug, color='r', align="center", width=0.55)

# Playing with aesthetics. 45 degrees xtick title, makes more legible
plt.xticks(tick_locations, list(num_of_meas_by_drug.index), rotation=45, fontsize = 12)
# Set x and y limits
plt.xlim(-0.7, len(x_axis)-0.2)
# max value y axis
plt.ylim(0, max(num_of_meas_by_drug)*1.08)

# Set a Title and labels
plt.xlabel("Drug Regimen",fontsize = 16, color='b')
plt.ylabel("Number of Treatments",fontsize = 16, color='b')
plt.title("Number of Measurements by Drug Regimen",fontsize = 18)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using PANDAS

# Collect data of 'Sex' from previous dataframe
sex_data = clean_df['Sex'].value_counts()

# plot and respective parameters
sex_pie = sex_data.plot(kind="pie",                   # Plot pie chart
                        figsize=(14, 8),              # total size of graph
                        autopct='%.2f',               # calculate % from dataframe value_counts for sex. Format % and 2 decimals
                        colors =["yellow","orange"],  # Chosen this colors to contract with black fonts and make legible
                        shadow=True,                  # shadow border, cosmetics
                        startangle=45,                # like this angle
                        fontsize=14)                  # bigger fontsize

# title and fontsize
sex_pie.set_title('Male vs. Female mice',fontsize = 16)

# Hide the 'y' label apper the word "sex" don't know why 
sex_pie.set_ylabel('')

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using PYPLOT

# Create Labels for pie segments
labels = ["Female","Male"]

#Set colors. Chosen this colors to contract with black fonts and make more legible
colors = ['yellow', 'orange']

#Create the pie chart based on previous sex_data dataframe

plt.figure(figsize=(14, 8))          # total size of graph
plt.pie(sex_data,                    # Plot pie chart
        labels=labels, 
        colors=colors, 
        autopct='%.2f',              # calculate % from dataframe value_counts for sex. Format % and 2 decimals 
        shadow=True,                 # shadow border, cosmetics
        textprops = {"fontsize":14}, # Font size of text in pie chart
        startangle=45,)              # like this angle

plt.title('Male vs Female mice', fontsize = 16) # title and fontsize

#Set equal axis
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# clean_df

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# generate dataframe from previous one keeping only columns needed for this calculations
reduced_df = clean_df[['Mouse ID','Drug Regimen','Timepoint', 'Tumor Volume (mm3)']]
# reduced_df
#-----------------------------------
# Select only certain drug regimens from previous dataframe and putting results in a new DF per
# 'Drug Regimen'

capomulin_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Capomulin",:]
ramicane_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Ramicane", :]
infubinol_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Infubinol", :]
ceftamin_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Ceftamin", :]

# append dataframes in a new dataframe
pick_drugs_df = capomulin_df
pick_drugs_df = pick_drugs_df.append(ramicane_df, ignore_index=True)
pick_drugs_df = pick_drugs_df.append(infubinol_df, ignore_index=True)
pick_drugs_df = pick_drugs_df.append(ceftamin_df, ignore_index=True)
  
# Start by getting the last (greatest) timepoint for each mouse
# Max it will be the max value for a Timepoint. Usually 45 days in this dataset
max_timepoint_df = pick_drugs_df[pick_drugs_df['Timepoint'] == pick_drugs_df['Timepoint'].max()]
# max_timepoint_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint--------------

# Rename columns to avoid conflicts
final_tumor_vol_df = max_timepoint_df.rename(columns={"Timepoint": "Max. timepoint", 
                                                               "Tumor Volume (mm3)": "Final tumor volume"})
# Drop unnecesary column that will be repeated after merging
final_tumor_vol_df = final_tumor_vol_df.drop(columns=['Drug Regimen'])
# final_tumor_vol_df

# Merge original dataframe with the df containing tumor volume at last timepoint
clean_data_merged_df = pd.merge(clean_df, final_tumor_vol_df, on='Mouse ID')

# Found in documentation that next option let show table in full. Can opt for .head() too
pd.set_option("display.max_rows", None, "display.max_columns", None)
clean_data_merged_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0       k403     Ramicane    Male          21          16          0
# 1       k403     Ramicane    Male          21          16          5
# 2       k403     Ramicane    Male          21          16         10
# 3       k403     Ramicane    Male          21          16         15
# 4       k403     Ramicane    Male          21          16         20
# 5       k403     Ramicane    Male          21          16         25
# 6       k403     Ramicane    Male          21          16         30
# 7       k403     Ramicane    Male          21          16         35
# 8       k403     Ramicane    Male          21          16         40
# 9       k403     Ramicane    Male          21          16         45
# 10      s185    Capomulin  Female           3          17          0
# 11      s185    Capomulin  Female           3          17          5
# 12      s185    Capomulin  Female           3          17         10
# 13      s185    Capomulin  Female           3          17         15
# 14      s185    Capomulin  Female           3          17         20
# 15      s185    Capomulin  Female           3          17         25
# 16      s185    Capomulin  Female           3          17         30
# 17      s185    Capomulin  Female           3          17         35
# 18      s185    Capomulin  Female           3          17         40
# 19      s185    Capomulin  Female           3          17         45
# 20      x401    Capomulin  Female          16          15          0
# 21      x401    Capomulin  Female          16          15          5
# 22      x401    Capomulin  Female          16          15         10
# 23      x401    Capomulin  Female          16          15         15
# 24      x401    Capomulin  Female          16          15         20
# 25      x401    Capomulin  Female          16          15         25
# 26      x401    Capomulin  Female          16          15         30
# 27      x401    Capomulin  Female          16          15         35
# 28      x401    Capomulin  Female          16          15         40
# 29      x401    Capomulin  Female          16          15         45
# 30      m601    Capomulin    Male          22          17          0
# 31      m601    Capomulin    Male          22          17          5
# 32      m601    Capomulin    Male          22          17         10
# 33      m601    Capomulin    Male          22          17         15
# 34      m601    Capomulin    Male          22          17         20
# 35      m601    Capomulin    Male          22          17         25
# 36      m601    Capomulin    Male          22          17         30
# 37      m601    Capomulin    Male          22          17         35
# 38      m601    Capomulin    Male          22          17         40
# 39      m601    Capomulin    Male          22          17         45
# 40      g791     Ramicane    Male          11          16          0
# 41      g791     Ramicane    Male          11          16          5
# 42      g791     Ramicane    Male          11          16         10
# 43      g791     Ramicane    Male          11          16         15
# 44      g791     Ramicane    Male          11          16         20
# 45      g791     Ramicane    Male          11          16         25
# 46      g791     Ramicane    Male          11          16         30
# 47      g791     Ramicane    Male          11          16         35
# 48      g791     Ramicane    Male          11          16         40
# 49      g791     Ramicane    Male          11          16         45
# 50      s508     Ramicane    Male           1          17          0
# 51      s508     Ramicane    Male           1          17          5
# 52      s508     Ramicane    Male           1          17         10
# 53      s508     Ramicane    Male           1          17         15
# 54      s508     Ramicane    Male           1          17         20
# 55      s508     Ramicane    Male           1          17         25
# 56      s508     Ramicane    Male           1          17         30
# 57      s508     Ramicane    Male           1          17         35
# 58      s508     Ramicane    Male           1          17         40
# 59      s508     Ramicane    Male           1          17         45
# 60      m546     Ramicane    Male          18          16          0
# 61      m546     Ramicane    Male          18          16          5
# 62      m546     Ramicane    Male          18          16         10
# 63      m546     Ramicane    Male          18          16         15
# 64      m546     Ramicane    Male          18          16         20
# 65      m546     Ramicane    Male          18          16         25
# 66      m546     Ramicane    Male          18          16         30
# 67      m546     Ramicane    Male          18          16         35
# 68      m546     Ramicane    Male          18          16         40
# 69      m546     Ramicane    Male          18          16         45
# 70      z578     Ramicane    Male          11          16          0
# 71      z578     Ramicane    Male          11          16          5
# 72      z578     Ramicane    Male          11          16         10
# 73      z578     Ramicane    Male          11          16         15
# 74      z578     Ramicane    Male          11          16         20
# 75      z578     Ramicane    Male          11          16         25
# 76      z578     Ramicane    Male          11          16         30
# 77      z578     Ramicane    Male          11          16         35
# 78      z578     Ramicane    Male          11          16         40
# 79      z578     Ramicane    Male          11          16         45
# 80      j913     Ramicane  Female           4          17          0
# 81      j913     Ramicane  Female           4          17          5
# 82      j913     Ramicane  Female           4          17         10
# 83      j913     Ramicane  Female           4          17         15
# 84      j913     Ramicane  Female           4          17         20
# 85      j913     Ramicane  Female           4          17         25
# 86      j913     Ramicane  Female           4          17         30
# 87      j913     Ramicane  Female           4          17         35
# 88      j913     Ramicane  Female           4          17         40
# 89      j913     Ramicane  Female           4          17         45
# 90      u364    Capomulin    Male          18          17          0
# 91      u364    Capomulin    Male          18          17          5
# 92      u364    Capomulin    Male          18          17         10
# 93      u364    Capomulin    Male          18          17         15
# 94      u364    Capomulin    Male          18          17         20
# 95      u364    Capomulin    Male          18          17         25
# 96      u364    Capomulin    Male          18          17         30
# 97      u364    Capomulin    Male          18          17         35
# 98      u364    Capomulin    Male          18          17         40
# 99      u364    Capomulin    Male          18          17         45
# 100     n364     Ramicane    Male           4          17          0
# 101     n364     Ramicane    Male           4          17          5
# 102     n364     Ramicane    Male           4          17         10
# 103     n364     Ramicane    Male           4          17         15
# 104     n364     Ramicane    Male           4          17         20
# 105     n364     Ramicane    Male           4          17         25
# 106     n364     Ramicane    Male           4          17         30
# 107     n364     Ramicane    Male           4          17         35
# 108     n364     Ramicane    Male           4          17         40
# 109     n364     Ramicane    Male           4          17         45
# 110     y793    Capomulin    Male          17          17          0
# 111     y793    Capomulin    Male          17          17          5
# 112     y793    Capomulin    Male          17          17         10
# 113     y793    Capomulin    Male          17          17         15
# 114     y793    Capomulin    Male          17          17         20
# 115     y793    Capomulin    Male          17          17         25
# 116     y793    Capomulin    Male          17          17         30
# 117     y793    Capomulin    Male          17          17         35
# 118     y793    Capomulin    Male          17          17         40
# 119     y793    Capomulin    Male          17          17         45
# 120     r554    Capomulin  Female           8          17          0
# 121     r554    Capomulin  Female           8          17          5
# 122     r554    Capomulin  Female           8          17         10
# 123     r554    Capomulin  Female           8          17         15
# 124     r554    Capomulin  Female           8          17         20
# 125     r554    Capomulin  Female           8          17         25
# 126     r554    Capomulin  Female           8          17         30
# 127     r554    Capomulin  Female           8          17         35
# 128     r554    Capomulin  Female           8          17         40
# 129     r554    Capomulin  Female           8          17         45
# 130     m957    Capomulin  Female           3          19          0
# 131     m957    Capomulin  Female           3          19          5
# 132     m957    Capomulin  Female           3          19         10
# 133     m957    Capomulin  Female           3          19         15
# 134     m957    Capomulin  Female           3          19         20
# 135     m957    Capomulin  Female           3          19         25
# 136     m957    Capomulin  Female           3          19         30
# 137     m957    Capomulin  Female           3          19         35
# 138     m957    Capomulin  Female           3          19         40
# 139     m957    Capomulin  Female           3          19         45
# 140     c758     Ramicane    Male           9          17          0
# 141     c758     Ramicane    Male           9          17          5
# 142     c758     Ramicane    Male           9          17         10
# 143     c758     Ramicane    Male           9          17         15
# 144     c758     Ramicane    Male           9          17         20
# 145     c758     Ramicane    Male           9          17         25
# 146     c758     Ramicane    Male           9          17         30
# 147     c758     Ramicane    Male           9          17         35
# 148     c758     Ramicane    Male           9          17         40
# 149     c758     Ramicane    Male           9          17         45
# 150     t565    Capomulin  Female          20          17          0
# 151     t565    Capomulin  Female          20          17          5
# 152     t565    Capomulin  Female          20          17         10
# 153     t565    Capomulin  Female          20          17         15
# 154     t565    Capomulin  Female          20          17         20
# 155     t565    Capomulin  Female          20          17         25
# 156     t565    Capomulin  Female          20          17         30
# 157     t565    Capomulin  Female          20          17         35
# 158     t565    Capomulin  Female          20          17         40
# 159     t565    Capomulin  Female          20          17         45
# 160     a644     Ramicane  Female           7          17          0
# 161     a644     Ramicane  Female           7          17          5
# 162     a644     Ramicane  Female           7          17         10
# 163     a644     Ramicane  Female           7          17         15
# 164     a644     Ramicane  Female           7          17         20
# 165     a644     Ramicane  Female           7          17         25
# 166     a644     Ramicane  Female           7          17         30
# 167     a644     Ramicane  Female           7          17         35
# 168     a644     Ramicane  Female           7          17         40
# 169     a644     Ramicane  Female           7          17         45
# 170     i177     Ramicane    Male          10          18          0
# 171     i177     Ramicane    Male          10          18          5
# 172     i177     Ramicane    Male          10          18         10
# 173     i177     Ramicane    Male          10          18         15
# 174     i177     Ramicane    Male          10          18         20
# 175     i177     Ramicane    Male          10          18         25
# 176     i177     Ramicane    Male          10          18         30
# 177     i177     Ramicane    Male          10          18         35
# 178     i177     Ramicane    Male          10          18         40
# 179     i177     Ramicane    Male          10          18         45
# 180     j989     Ramicane    Male           8          19          0
# 181     j989     Ramicane    Male           8          19          5
# 182     j989     Ramicane    Male           8          19         10
# 183     j989     Ramicane    Male           8          19         15
# 184     j989     Ramicane    Male           8          19         20
# 185     j989     Ramicane    Male           8          19         25
# 186     j989     Ramicane    Male           8          19         30
# 187     j989     Ramicane    Male           8          19         35
# 188     j989     Ramicane    Male           8          19         40
# 189     j989     Ramicane    Male           8          19         45
# 190     i738    Capomulin  Female          23          20          0
# 191     i738    Capomulin  Female          23          20          5
# 192     i738    Capomulin  Female          23          20         10
# 193     i738    Capomulin  Female          23          20         15
# 194     i738    Capomulin  Female          23          20         20
# 195     i738    Capomulin  Female          23          20         25
# 196     i738    Capomulin  Female          23          20         30
# 197     i738    Capomulin  Female          23          20         35
# 198     i738    Capomulin  Female          23          20         40
# 199     i738    Capomulin  Female          23          20         45
# 200     a520     Ramicane    Male          13          21          0
# 201     a520     Ramicane    Male          13          21          5
# 202     a520     Ramicane    Male          13          21         10
# 203     a520     Ramicane    Male          13          21         15
# 204     a520     Ramicane    Male          13          21         20
# 205     a520     Ramicane    Male          13          21         25
# 206     a520     Ramicane    Male          13          21         30
# 207     a520     Ramicane    Male          13          21         35
# 208     a520     Ramicane    Male          13          21         40
# 209     a520     Ramicane    Male          13          21         45
# 210     w914    Capomulin    Male          24          21          0
# 211     w914    Capomulin    Male          24          21          5
# 212     w914    Capomulin    Male          24          21         10
# 213     w914    Capomulin    Male          24          21         15
# 214     w914    Capomulin    Male          24          21         20
# 215     w914    Capomulin    Male          24          21         25
# 216     w914    Capomulin    Male          24          21         30
# 217     w914    Capomulin    Male          24          21         35
# 218     w914    Capomulin    Male          24          21         40
# 219     w914    Capomulin    Male          24          21         45
# 220     r811     Ramicane    Male           9          19          0
# 221     r811     Ramicane    Male           9          19          5
# 222     r811     Ramicane    Male           9          19         10
# 223     r811     Ramicane    Male           9          19         15
# 224     r811     Ramicane    Male           9          19         20
# 225     r811     Ramicane    Male           9          19         25
# 226     r811     Ramicane    Male           9          19         30
# 227     r811     Ramicane    Male           9          19         35
# 228     r811     Ramicane    Male           9          19         40
# 229     r811     Ramicane    Male           9          19         45
# 230     g288    Capomulin    Male           3          19          0
# 231     g288    Capomulin    Male           3          19          5
# 232     g288    Capomulin    Male           3          19         10
# 233     g288    Capomulin    Male           3          19         15
# 234     g288    Capomulin    Male           3          19         20
# 235     g288    Capomulin    Male           3          19         25
# 236     g288    Capomulin    Male           3          19         30
# 237     g288    Capomulin    Male           3          19         35
# 238     g288    Capomulin    Male           3          19         40
# 239     g288    Capomulin    Male           3          19         45
# 240     i334     Ramicane  Female           8          20          0
# 241     i334     Ramicane  Female           8          20          5
# 242     i334     Ramicane  Female           8          20         10
# 243     i334     Ramicane  Female           8          20         15
# 244     i334     Ramicane  Female           8          20         20
# 245     i334     Ramicane  Female           8          20         25
# 246     i334     Ramicane  Female           8          20         30
# 247     i334     Ramicane  Female           8          20         35
# 248     i334     Ramicane  Female           8          20         40
# 249     i334     Ramicane  Female           8          20         45
# 250     d251     Ramicane  Female           8          19          0
# 251     d251     Ramicane  Female           8          19          5
# 252     d251     Ramicane  Female           8          19         10
# 253     d251     Ramicane  Female           8          19         15
# 254     d251     Ramicane  Female           8          19         20
# 255     d251     Ramicane  Female           8          19         25
# 256     d251     Ramicane  Female           8          19         30
# 257     d251     Ramicane  Female           8          19         35
# 258     d251     Ramicane  Female           8          19         40
# 259     d251     Ramicane  Female           8          19         45
# 260     l897    Capomulin    Male          17          19          0
# 261     l897    Capomulin    Male          17          19          5
# 262     l897    Capomulin    Male          17          19         10
# 263     l897    Capomulin    Male          17          19         15
# 264     l897    Capomulin    Male          17          19         20
# 265     l897    Capomulin    Male          17          19         25
# 266     l897    Capomulin    Male          17          19         30
# 267     l897    Capomulin    Male          17          19         35
# 268     l897    Capomulin    Male          17          19         40
# 269     l897    Capomulin    Male          17          19         45
# 270     b742    Capomulin    Male           7          21          0
# 271     b742    Capomulin    Male           7          21          5
# 272     b742    Capomulin    Male           7          21         10
# 273     b742    Capomulin    Male           7          21         15
# 274     b742    Capomulin    Male           7          21         20
# 275     b742    Capomulin    Male           7          21         25
# 276     b742    Capomulin    Male           7          21         30
# 277     b742    Capomulin    Male           7          21         35
# 278     b742    Capomulin    Male           7          21         40
# 279     b742    Capomulin    Male           7          21         45
# 280     b128    Capomulin  Female           9          22          0
# 281     b128    Capomulin  Female           9          22          5
# 282     b128    Capomulin  Female           9          22         10
# 283     b128    Capomulin  Female           9          22         15
# 284     b128    Capomulin  Female           9          22         20
# 285     b128    Capomulin  Female           9          22         25
# 286     b128    Capomulin  Female           9          22         30
# 287     b128    Capomulin  Female           9          22         35
# 288     b128    Capomulin  Female           9          22         40
# 289     b128    Capomulin  Female           9          22         45
# 290     a411     Ramicane    Male           3          22          0
# 291     a411     Ramicane    Male           3          22          5
# 292     a411     Ramicane    Male           3          22         10
# 293     a411     Ramicane    Male           3          22         15
# 294     a411     Ramicane    Male           3          22         20
# 295     a411     Ramicane    Male           3          22         25
# 296     a411     Ramicane    Male           3          22         30
# 297     a411     Ramicane    Male           3          22         35
# 298     a411     Ramicane    Male           3          22         40
# 299     a411     Ramicane    Male           3          22         45
# 300     j119    Capomulin  Female           7          23          0
# 301     j119    Capomulin  Female           7          23          5
# 302     j119    Capomulin  Female           7          23         10
# 303     j119    Capomulin  Female           7          23         15
# 304     j119    Capomulin  Female           7          23         20
# 305     j119    Capomulin  Female           7          23         25
# 306     j119    Capomulin  Female           7          23         30
# 307     j119    Capomulin  Female           7          23         35
# 308     j119    Capomulin  Female           7          23         40
# 309     j119    Capomulin  Female           7          23         45
# 310     v923    Capomulin  Female          19          21          0
# 311     v923    Capomulin  Female          19          21          5
# 312     v923    Capomulin  Female          19          21         10
# 313     v923    Capomulin  Female          19          21         15
# 314     v923    Capomulin  Female          19          21         20
# 315     v923    Capomulin  Female          19          21         25
# 316     v923    Capomulin  Female          19          21         30
# 317     v923    Capomulin  Female          19          21         35
# 318     v923    Capomulin  Female          19          21         40
# 319     v923    Capomulin  Female          19          21         45
# 320     g316    Capomulin  Female          22          22          0
# 321     g316    Capomulin  Female          22          22          5
# 322     g316    Capomulin  Female          22          22         10
# 323     g316    Capomulin  Female          22          22         15
# 324     g316    Capomulin  Female          22          22         20
# 325     g316    Capomulin  Female          22          22         25
# 326     g316    Capomulin  Female          22          22         30
# 327     g316    Capomulin  Female          22          22         35
# 328     g316    Capomulin  Female          22          22         40
# 329     g316    Capomulin  Female          22          22         45
# 330     s710    Capomulin  Female           1          23          0
# 331     s710    Capomulin  Female           1          23          5
# 332     s710    Capomulin  Female           1          23         10
# 333     s710    Capomulin  Female           1          23         15
# 334     s710    Capomulin  Female           1          23         20
# 335     s710    Capomulin  Female           1          23         25
# 336     s710    Capomulin  Female           1          23         30
# 337     s710    Capomulin  Female           1          23         35
# 338     s710    Capomulin  Female           1          23         40
# 339     s710    Capomulin  Female           1          23         45
# 340     l509    Capomulin    Male          17          21          0
# 341     l509    Capomulin    Male          17          21          5
# 342     l509    Capomulin    Male          17          21         10
# 343     l509    Capomulin    Male          17          21         15
# 344     l509    Capomulin    Male          17          21         20
# 345     l509    Capomulin    Male          17          21         25
# 346     l509    Capomulin    Male          17          21         30
# 347     l509    Capomulin    Male          17          21         35
# 348     l509    Capomulin    Male          17          21         40
# 349     l509    Capomulin    Male          17          21         45
# 350     r944    Capomulin    Male          12          25          0
# 351     r944    Capomulin    Male          12          25          5
# 352     r944    Capomulin    Male          12          25         10
# 353     r944    Capomulin    Male          12          25         15
# 354     r944    Capomulin    Male          12          25         20
# 355     r944    Capomulin    Male          12          25         25
# 356     r944    Capomulin    Male          12          25         30
# 357     r944    Capomulin    Male          12          25         35
# 358     r944    Capomulin    Male          12          25         40
# 359     r944    Capomulin    Male          12          25         45
# 360     e662     Ramicane    Male           8          24          0
# 361     e662     Ramicane    Male           8          24          5
# 362     e662     Ramicane    Male           8          24         10
# 363     e662     Ramicane    Male           8          24         15
# 364     e662     Ramicane    Male           8          24         20
# 365     e662     Ramicane    Male           8          24         25
# 366     e662     Ramicane    Male           8          24         30
# 367     e662     Ramicane    Male           8          24         35
# 368     e662     Ramicane    Male           8          24         40
# 369     e662     Ramicane    Male           8          24         45
# 370     u196     Ramicane    Male          18          25          0
# 371     u196     Ramicane    Male          18          25          5
# 372     u196     Ramicane    Male          18          25         10
# 373     u196     Ramicane    Male          18          25         15
# 374     u196     Ramicane    Male          18          25         20
# 375     u196     Ramicane    Male          18          25         25
# 376     u196     Ramicane    Male          18          25         30
# 377     u196     Ramicane    Male          18          25         35
# 378     u196     Ramicane    Male          18          25         40
# 379     u196     Ramicane    Male          18          25         45
# 380     q597     Ramicane    Male          20          25          0
# 381     q597     Ramicane    Male          20          25          5
# 382     q597     Ramicane    Male          20          25         10
# 383     q597     Ramicane    Male          20          25         15
# 384     q597     Ramicane    Male          20          25         20
# 385     q597     Ramicane    Male          20          25         25
# 386     q597     Ramicane    Male          20          25         30
# 387     q597     Ramicane    Male          20          25         35
# 388     q597     Ramicane    Male          20          25         40
# 389     q597     Ramicane    Male          20          25         45
# 390     a444     Ramicane  Female          10          25          0
# 391     a444     Ramicane  Female          10          25          5
# 392     a444     Ramicane  Female          10          25         10
# 393     a444     Ramicane  Female          10          25         15
# 394     a444     Ramicane  Female          10          25         20
# 395     a444     Ramicane  Female          10          25         25
# 396     a444     Ramicane  Female          10          25         30
# 397     a444     Ramicane  Female          10          25         35
# 398     a444     Ramicane  Female          10          25         40
# 399     a444     Ramicane  Female          10          25         45
# 400     i557    Capomulin  Female           1          24          0
# 401     i557    Capomulin  Female           1          24          5
# 402     i557    Capomulin  Female           1          24         10
# 403     i557    Capomulin  Female           1          24         15
# 404     i557    Capomulin  Female           1          24         20
# 405     i557    Capomulin  Female           1          24         25
# 406     i557    Capomulin  Female           1          24         30
# 407     i557    Capomulin  Female           1          24         35
# 408     i557    Capomulin  Female           1          24         40
# 409     i557    Capomulin  Female           1          24         45
# 410     a203    Infubinol  Female          20          23          0
# 411     a203    Infubinol  Female          20          23          5
# 412     a203    Infubinol  Female          20          23         10
# 413     a203    Infubinol  Female          20          23         15
# 414     a203    Infubinol  Female          20          23         20
# 415     a203    Infubinol  Female          20          23         25
# 416     a203    Infubinol  Female          20          23         30
# 417     a203    Infubinol  Female          20          23         35
# 418     a203    Infubinol  Female          20          23         40
# 419     a203    Infubinol  Female          20          23         45
# 420     a251    Infubinol  Female          21          25          0
# 421     a251    Infubinol  Female          21          25          5
# 422     a251    Infubinol  Female          21          25         10
# 423     a251    Infubinol  Female          21          25         15
# 424     a251    Infubinol  Female          21          25         20
# 425     a251    Infubinol  Female          21          25         25
# 426     a251    Infubinol  Female          21          25         30
# 427     a251    Infubinol  Female          21          25         35
# 428     a251    Infubinol  Female          21          25         40
# 429     a251    Infubinol  Female          21          25         45
# 430     a275     Ceftamin  Female          20          28          0
# 431     a275     Ceftamin  Female          20          28          5
# 432     a275     Ceftamin  Female          20          28         10
# 433     a275     Ceftamin  Female          20          28         15
# 434     a275     Ceftamin  Female          20          28         20
# 435     a275     Ceftamin  Female          20          28         25
# 436     a275     Ceftamin  Female          20          28         30
# 437     a275     Ceftamin  Female          20          28         35
# 438     a275     Ceftamin  Female          20          28         40
# 439     a275     Ceftamin  Female          20          28         45
# 440     a685    Infubinol    Male           8          30          0
# 441     a685    Infubinol    Male           8          30          5
# 442     a685    Infubinol    Male           8          30         10
# 443     a685    Infubinol    Male           8          30         15
# 444     a685    Infubinol    Male           8          30         20
# 445     a685    Infubinol    Male           8          30         25
# 446     a685    Infubinol    Male           8          30         30
# 447     a685    Infubinol    Male           8          30         35
# 448     a685    Infubinol    Male           8          30         40
# 449     a685    Infubinol    Male           8          30         45
# 450     c139    Infubinol    Male          11          28          0
# 451     c139    Infubinol    Male          11          28          5
# 452     c139    Infubinol    Male          11          28         10
# 453     c139    Infubinol    Male          11          28         15
# 454     c139    Infubinol    Male          11          28         20
# 455     c139    Infubinol    Male          11          28         25
# 456     c139    Infubinol    Male          11          28         30
# 457     c139    Infubinol    Male          11          28         35
# 458     c139    Infubinol    Male          11          28         40
# 459     c139    Infubinol    Male          11          28         45
# 460     e476    Infubinol    Male          23          26          0
# 461     e476    Infubinol    Male          23          26          5
# 462     e476    Infubinol    Male          23          26         10
# 463     e476    Infubinol    Male          23          26         15
# 464     e476    Infubinol    Male          23          26         20
# 465     e476    Infubinol    Male          23          26         25
# 466     e476    Infubinol    Male          23          26         30
# 467     e476    Infubinol    Male          23          26         35
# 468     e476    Infubinol    Male          23          26         40
# 469     e476    Infubinol    Male          23          26         45
# 470     f345    Infubinol    Male          23          26          0
# 471     f345    Infubinol    Male          23          26          5
# 472     f345    Infubinol    Male          23          26         10
# 473     f345    Infubinol    Male          23          26         15
# 474     f345    Infubinol    Male          23          26         20
# 475     f345    Infubinol    Male          23          26         25
# 476     f345    Infubinol    Male          23          26         30
# 477     f345    Infubinol    Male          23          26         35
# 478     f345    Infubinol    Male          23          26         40
# 479     f345    Infubinol    Male          23          26         45
# 480     j296     Ceftamin  Female          24          30          0
# 481     j296     Ceftamin  Female          24          30          5
# 482     j296     Ceftamin  Female          24          30         10
# 483     j296     Ceftamin  Female          24          30         15
# 484     j296     Ceftamin  Female          24          30         20
# 485     j296     Ceftamin  Female          24          30         25
# 486     j296     Ceftamin  Female          24          30         30
# 487     j296     Ceftamin  Female          24          30         35
# 488     j296     Ceftamin  Female          24          30         40
# 489     j296     Ceftamin  Female          24          30         45
# 490     k210     Ceftamin    Male          15          28          0
# 491     k210     Ceftamin    Male          15          28          5
# 492     k210     Ceftamin    Male          15          28         10
# 493     k210     Ceftamin    Male          15          28         15
# 494     k210     Ceftamin    Male          15          28         20
# 495     k210     Ceftamin    Male          15          28         25
# 496     k210     Ceftamin    Male          15          28         30
# 497     k210     Ceftamin    Male          15          28         35
# 498     k210     Ceftamin    Male          15          28         40
# 499     k210     Ceftamin    Male          15          28         45
# 500     k483    Infubinol  Female          20          30          0
# 501     k483    Infubinol  Female          20          30          5
# 502     k483    Infubinol  Female          20          30         10
# 503     k483    Infubinol  Female          20          30         15
# 504     k483    Infubinol  Female          20          30         20
# 505     k483    Infubinol  Female          20          30         25
# 506     k483    Infubinol  Female          20          30         30
# 507     k483    Infubinol  Female          20          30         35
# 508     k483    Infubinol  Female          20          30         40
# 509     k483    Infubinol  Female          20          30         45
# 510     l471     Ceftamin  Female           7          28          0
# 511     l471     Ceftamin  Female           7          28          5
# 512     l471     Ceftamin  Female           7          28         10
# 513     l471     Ceftamin  Female           7          28         15
# 514     l471     Ceftamin  Female           7          28         20
# 515     l471     Ceftamin  Female           7          28         25
# 516     l471     Ceftamin  Female           7          28         30
# 517     l471     Ceftamin  Female           7          28         35
# 518     l471     Ceftamin  Female           7          28         40
# 519     l471     Ceftamin  Female           7          28         45
# 520     l661     Ceftamin    Male          18          26          0
# 521     l661     Ceftamin    Male          18          26          5
# 522     l661     Ceftamin    Male          18          26         10
# 523     l661     Ceftamin    Male          18          26         15
# 524     l661     Ceftamin    Male          18          26         20
# 525     l661     Ceftamin    Male          18          26         25
# 526     l661     Ceftamin    Male          18          26         30
# 527     l661     Ceftamin    Male          18          26         35
# 528     l661     Ceftamin    Male          18          26         40
# 529     l661     Ceftamin    Male          18          26         45
# 530     l733     Ceftamin  Female           4          30          0
# 531     l733     Ceftamin  Female           4          30          5
# 532     l733     Ceftamin  Female           4          30         10
# 533     l733     Ceftamin  Female           4          30         15
# 534     l733     Ceftamin  Female           4          30         20
# 535     l733     Ceftamin  Female           4          30         25
# 536     l733     Ceftamin  Female           4          30         30
# 537     l733     Ceftamin  Female           4          30         35
# 538     l733     Ceftamin  Female           4          30         40
# 539     l733     Ceftamin  Female           4          30         45
# 540     o287     Ceftamin    Male           2          28          0
# 541     o287     Ceftamin    Male           2          28          5
# 542     o287     Ceftamin    Male           2          28         10
# 543     o287     Ceftamin    Male           2          28         15
# 544     o287     Ceftamin    Male           2          28         20
# 545     o287     Ceftamin    Male           2          28         25
# 546     o287     Ceftamin    Male           2          28         30
# 547     o287     Ceftamin    Male           2          28         35
# 548     o287     Ceftamin    Male           2          28         40
# 549     o287     Ceftamin    Male           2          28         45
# 550     p438     Ceftamin  Female          11          26          0
# 551     p438     Ceftamin  Female          11          26          5
# 552     p438     Ceftamin  Female          11          26         10
# 553     p438     Ceftamin  Female          11          26         15
# 554     p438     Ceftamin  Female          11          26         20
# 555     p438     Ceftamin  Female          11          26         25
# 556     p438     Ceftamin  Female          11          26         30
# 557     p438     Ceftamin  Female          11          26         35
# 558     p438     Ceftamin  Female          11          26         40
# 559     p438     Ceftamin  Female          11          26         45
# 560     w151     Ceftamin    Male          24          25          0
# 561     w151     Ceftamin    Male          24          25          5
# 562     w151     Ceftamin    Male          24          25         10
# 563     w151     Ceftamin    Male          24          25         15
# 564     w151     Ceftamin    Male          24          25         20
# 565     w151     Ceftamin    Male          24          25         25
# 566     w151     Ceftamin    Male          24          25         30
# 567     w151     Ceftamin    Male          24          25         35
# 568     w151     Ceftamin    Male          24          25         40
# 569     w151     Ceftamin    Male          24          25         45
# 570     x581     Ceftamin  Female          19          28          0
# 571     x581     Ceftamin  Female          19          28          5
# 572     x581     Ceftamin  Female          19          28         10
# 573     x581     Ceftamin  Female          19          28         15
# 574     x581     Ceftamin  Female          19          28         20
# 575     x581     Ceftamin  Female          19          28         25
# 576     x581     Ceftamin  Female          19          28         30
# 577     x581     Ceftamin  Female          19          28         35
# 578     x581     Ceftamin  Female          19          28         40
# 579     x581     Ceftamin  Female          19          28         45
# 580     x822     Ceftamin    Male           3          29          0
# 581     x822     Ceftamin    Male           3          29          5
# 582     x822     Ceftamin    Male           3          29         10
# 583     x822     Ceftamin    Male           3          29         15
# 584     x822     Ceftamin    Male           3          29         20
# 585     x822     Ceftamin    Male           3          29         25
# 586     x822     Ceftamin    Male           3          29         30
# 587     x822     Ceftamin    Male           3          29         35
# 588     x822     Ceftamin    Male           3          29         40
# 589     x822     Ceftamin    Male           3          29         45
# 590     y163    Infubinol  Female          17          27          0
# 591     y163    Infubinol  Female          17          27          5
# 592     y163    Infubinol  Female          17          27         10
# 593     y163    Infubinol  Female          17          27         15
# 594     y163    Infubinol  Female          17          27         20
# 595     y163    Infubinol  Female          17          27         25
# 596     y163    Infubinol  Female          17          27         30
# 597     y163    Infubinol  Female          17          27         35
# 598     y163    Infubinol  Female          17          27         40
# 599     y163    Infubinol  Female          17          27         45
# 600     y769     Ceftamin  Female           6          27          0
# 601     y769     Ceftamin  Female           6          27          5
# 602     y769     Ceftamin  Female           6          27         10
# 603     y769     Ceftamin  Female           6          27         15
# 604     y769     Ceftamin  Female           6          27         20
# 605     y769     Ceftamin  Female           6          27         25
# 606     y769     Ceftamin  Female           6          27         30
# 607     y769     Ceftamin  Female           6          27         35
# 608     y769     Ceftamin  Female           6          27         40
# 609     y769     Ceftamin  Female           6          27         45
# 610     y865     Ceftamin    Male          23          26          0
# 611     y865     Ceftamin    Male          23          26          5
# 612     y865     Ceftamin    Male          23          26         10
# 613     y865     Ceftamin    Male          23          26         15
# 614     y865     Ceftamin    Male          23          26         20
# 615     y865     Ceftamin    Male          23          26         25
# 616     y865     Ceftamin    Male          23          26         30
# 617     y865     Ceftamin    Male          23          26         35
# 618     y865     Ceftamin    Male          23          26         40
# 619     y865     Ceftamin    Male          23          26         45
# 620     z581    Infubinol  Female          24          25          0
# 621     z581    Infubinol  Female          24          25          5
# 622     z581    Infubinol  Female          24          25         10
# 623     z581    Infubinol  Female          24          25         15
# 624     z581    Infubinol  Female          24          25         20
# 625     z581    Infubinol  Female          24          25         25
# 626     z581    Infubinol  Female          24          25         30
# 627     z581    Infubinol  Female          24          25         35
# 628     z581    Infubinol  Female          24          25         40
# 629     z581    Infubinol  Female          24          25         45
#
#      Tumor Volume (mm3)  Metastatic Sites  Max. timepoint  Final tumor volume
# 0             45.000000                 0              45           22.050126
# 1             38.825898                 0              45           22.050126
# 2             35.014271                 1              45           22.050126
# 3             34.223992                 1              45           22.050126
# 4             32.997729                 1              45           22.050126
# 5             33.464577                 1              45           22.050126
# 6             31.099498                 1              45           22.050126
# 7             26.546993                 1              45           22.050126
# 8             24.365505                 1              45           22.050126
# 9             22.050126                 1              45           22.050126
# 10            45.000000                 0              45           23.343598
# 11            43.878496                 0              45           23.343598
# 12            37.614948                 0              45           23.343598
# 13            38.177232                 0              45           23.343598
# 14            36.866876                 0              45           23.343598
# 15            33.949940                 0              45           23.343598
# 16            32.959671                 1              45           23.343598
# 17            28.328531                 1              45           23.343598
# 18            25.472143                 1              45           23.343598
# 19            23.343598                 1              45           23.343598
# 20            45.000000                 0              45           28.484033
# 21            45.473753                 0              45           28.484033
# 22            39.113891                 0              45           28.484033
# 23            39.776250                 0              45           28.484033
# 24            36.065835                 0              45           28.484033
# 25            36.617120                 0              45           28.484033
# 26            32.915292                 0              45           28.484033
# 27            30.206825                 0              45           28.484033
# 28            28.167397                 0              45           28.484033
# 29            28.484033                 0              45           28.484033
# 30            45.000000                 0              45           28.430964
# ...
# 430           45.000000                 0              45           62.999356
# 431           46.795257                 0              45           62.999356
# 432           47.371343                 0              45           62.999356
# 433           49.734404                 0              45           62.999356
# 434           50.513437                 1              45           62.999356
# 435           53.576064                 1              45           62.999356
# 436           54.444713                 2              45           62.999356
# 437           56.353538                 2              45           62.999356
# 438           60.921539                 3              45           62.999356
# 439           62.999356                 3              45           62.999356
# 440           45.000000                 0              45           66.083066
# 441           46.870483                 0              45           66.083066
# 442           47.664753                 0              45           66.083066
# 443           48.951474                 0              45           66.083066
# 444           49.490559                 0              45           66.083066
# 445           51.939951                 0              45           66.083066
# 446           55.453855                 1              45           66.083066
# 447           58.092629                 1              45           66.083066
# 448           60.567904                 2              45           66.083066
# 449           66.083066                 3              45           66.083066
# 450           45.000000                 0              45           72.226731
# 451           48.753112                 0              45           72.226731
# 452           49.992954                 0              45           72.226731
# 453           51.833225                 0              45           72.226731
# 454           56.742007                 0              45           72.226731
# 455           61.461970                 0              45           72.226731
# 456           64.149871                 1              45           72.226731
# 457           67.821420                 1              45           72.226731
# 458           69.428141                 2              45           72.226731
# 459           72.226731                 2              45           72.226731
# 460           45.000000                 0              45           62.435404
# 461           47.111801                 0              45           62.435404
# 462           49.431685                 0              45           62.435404
# 463           54.046213                 0              45           62.435404
# 464           55.249273                 0              45           62.435404
# 465           57.408638                 0              45           62.435404
# 466           57.992797                 1              45           62.435404
# 467           60.064340                 1              45           62.435404
# 468           61.525276                 1              45           62.435404
# 469           62.435404                 1              45           62.435404
# 470           45.000000                 0              45           60.918767
# 471           45.591147                 0              45           60.918767
# 472           47.222446                 0              45           60.918767
# 473           48.352239                 0              45           60.918767
# 474           49.613383                 0              45           60.918767
# 475           53.078894                 0              45           60.918767
# 476           54.363797                 1              45           60.918767
# 477           56.523327                 1              45           60.918767
# 478           58.315593                 1              45           60.918767
# 479           60.918767                 1              45           60.918767
# 480           45.000000                 0              45           61.849023
# 481           46.799256                 1              45           61.849023
# 482           48.529978                 2              45           61.849023
# 483           50.701280                 2              45           61.849023
# 484           54.005342                 3              45           61.849023
# 485           55.767148                 3              45           61.849023
# 486           56.803061                 3              45           61.849023
# 487           58.714483                 3              45           61.849023
# 488           60.072688                 3              45           61.849023
# 489           61.849023                 3              45           61.849023
# 490           45.000000                 0              45           68.923185
# 491           47.918998                 0              45           68.923185
# 492           49.379932                 0              45           68.923185
# 493           51.073558                 0              45           68.923185
# 494           51.997619                 0              45           68.923185
# 495           54.613973                 0              45           68.923185
# 496           59.989510                 1              45           68.923185
# 497           63.329330                 1              45           68.923185
# 498           66.622836                 2              45           68.923185
# 499           68.923185                 3              45           68.923185
# 500           45.000000                 0              45           66.196912
# 501           46.611056                 0              45           66.196912
# 502           50.296041                 1              45           66.196912
# 503           53.244458                 1              45           66.196912
# 504           54.778961                 1              45           66.196912
# 505           57.432007                 2              45           66.196912
# 506           59.747077                 2              45           66.196912
# 507           60.541562                 2              45           66.196912
# 508           64.138725                 3              45           66.196912
# 509           66.196912                 3              45           66.196912
# 510           45.000000                 0              45           67.748662
# 511           46.251872                 0              45           67.748662
# 512           48.182063                 0              45           67.748662
# 513           49.406879                 0              45           67.748662
# 514           52.228327                 0              45           67.748662
# 515           52.847559                 1              45           67.748662
# 516           58.093604                 1              45           67.748662
# 517           61.405999                 1              45           67.748662
# 518           63.844858                 1              45           67.748662
# 519           67.748662                 1              45           67.748662
# 520           45.000000                 0              45           59.851956
# 521           46.268799                 0              45           59.851956
# 522           49.683620                 0              45           59.851956
# 523           50.947545                 1              45           59.851956
# 524           52.617490                 1              45           59.851956
# 525           53.180657                 2              45           59.851956
# 526           55.329099                 2              45           59.851956
# 527           56.474129                 2              45           59.851956
# 528           59.205669                 3              45           59.851956
# 529           59.851956                 3              45           59.851956
# 530           45.000000                 0              45           64.299830
# 531           46.174226                 0              45           64.299830
# 532           48.354952                 0              45           64.299830
# 533           49.285195                 0              45           64.299830
# 534           53.244312                 1              45           64.299830
# 535           54.951668                 1              45           64.299830
# 536           56.319065                 1              45           64.299830
# 537           57.600798                 1              45           64.299830
# 538           59.443506                 1              45           64.299830
# 539           64.299830                 1              45           64.299830
# 540           45.000000                 0              45           59.741901
# 541           45.586804                 0              45           59.741901
# 542           47.360201                 1              45           59.741901
# 543           48.679453                 1              45           59.741901
# 544           50.856141                 2              45           59.741901
# 545           52.068486                 3              45           59.741901
# 546           54.503001                 3              45           59.741901
# 547           55.118290                 4              45           59.741901
# 548           57.197193                 4              45           59.741901
# 549           59.741901                 4              45           59.741901
# 550           45.000000                 0              45           61.433892
# 551           46.827934                 0              45           61.433892
# 552           50.517498                 0              45           61.433892
# 553           52.198368                 0              45           61.433892
# 554           52.905299                 0              45           61.433892
# 555           54.510575                 0              45           61.433892
# 556           56.406422                 0              45           61.433892
# 557           57.538555                 1              45           61.433892
# 558           59.305288                 1              45           61.433892
# 559           61.433892                 1              45           61.433892
# 560           45.000000                 0              45           67.527482
# 561           45.546076                 1              45           67.527482
# 562           46.501476                 1              45           67.527482
# 563           47.242929                 1              45           67.527482
# 564           49.554263                 2              45           67.527482
# 565           51.869059                 2              45           67.527482
# 566           56.767158                 2              45           67.527482
# 567           58.339141                 2              45           67.527482
# 568           62.187950                 2              45           67.527482
# 569           67.527482                 3              45           67.527482
# 570           45.000000                 0              45           64.634949
# 571           47.196927                 0              45           64.634949
# 572           49.067028                 1              45           64.634949
# 573           49.746427                 2              45           64.634949
# 574           51.207969                 3              45           64.634949
# 575           51.935283                 3              45           64.634949
# 576           55.492826                 3              45           64.634949
# 577           58.077583                 3              45           64.634949
# 578           60.280405                 3              45           64.634949
# 579           64.634949                 3              45           64.634949
# 580           45.000000                 0              45           61.386660
# 581           45.671104                 1              45           61.386660
# 582           48.983717                 1              45           61.386660
# 583           49.694665                 1              45           61.386660
# 584           51.914910                 2              45           61.386660
# 585           54.041333                 2              45           61.386660
# 586           55.445155                 2              45           61.386660
# 587           56.796567                 2              45           61.386660
# 588           59.555685                 2              45           61.386660
# 589           61.386660                 3              45           61.386660
# 590           45.000000                 0              45           67.685569
# 591           48.284970                 0              45           67.685569
# 592           49.112399                 1              45           67.685569
# 593           51.523068                 1              45           67.685569
# 594           54.571076                 1              45           67.685569
# 595           56.176385                 1              45           67.685569
# 596           59.412537                 2              45           67.685569
# 597           61.730196                 2              45           67.685569
# 598           63.620680                 2              45           67.685569
# 599           67.685569                 3              45           67.685569
# 600           45.000000                 0              45           68.594745
# 601           46.422652                 1              45           68.594745
# 602           48.015163                 1              45           68.594745
# 603           52.761021                 2              45           68.594745
# 604           55.025724                 2              45           68.594745
# 605           58.335959                 3              45           68.594745
# 606           61.071949                 3              45           68.594745
# 607           63.430632                 3              45           68.594745
# 608           64.251028                 4              45           68.594745
# 609           68.594745                 4              45           68.594745
# 610           45.000000                 0              45           64.729837
# 611           46.735006                 1              45           64.729837
# 612           49.522740                 1              45           64.729837
# 613           50.806519                 1              45           64.729837
# 614           52.361982                 1              45           64.729837
# 615           57.173538                 2              45           64.729837
# 616           59.033275                 3              45           64.729837
# 617           61.153140                 3              45           64.729837
# 618           63.469549                 3              45           64.729837
# 619           64.729837                 3              45           64.729837
# 620           45.000000                 0              45           62.754451
# 621           49.273092                 1              45           62.754451
# 622           50.478750                 2              45           62.754451
# 623           51.196304                 2              45           62.754451
# 624           51.807944                 2              45           62.754451
# 625           54.316407                 2              45           62.754451
# 626           56.286750                 2              45           62.754451
# 627           58.628399                 3              45           62.754451
# 628           60.053740                 3              45           62.754451
# 629           62.754451                 3              45           62.754451

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
list_tumor_vol = []

# Begin loop for drugs
for treatment in treatments:
    
    # new dataframe from previous one that contained volume at last timepoint per drug.
    # but getting only ones looping 
    drug_df = max_timepoint_df[max_timepoint_df['Drug Regimen'] == treatment]
      
    # Drop unnecesary column that will be repeated after merging. Timepoint is the max
    drug_df = drug_df.drop(columns=['Timepoint'])

    # Create a series that consists of all final volume values for each regimen
    final_vol = drug_df['Tumor Volume (mm3)']
    list_tumor_vol.append(final_vol)

    # Calculate the IQR and quantitatively determine if there are any potential outliers.

    quartiles = final_vol.quantile([.25,.5,.75]) # Set quartiles at 25%, 50%, 75%
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq        # Calculate interquartile range 3rd minus 1st quartile

    print(" ")     # empty line with space to separate drug results
    print(f'The interquartile range for {treatment} is: {iqr}')

    # Find upper and lower bounds to help identify outliers for each regimen ASTONISHING CONCLUSION
    lower_bound = lowerq - (1.5*iqr)           # lowerbound as defined in course to determine outliers below
    upper_bound = upperq + (1.5*iqr)           # upperbound as defined in course to determine outliers over
    print(f'The lower quartile for {treatment} is: {lowerq}')
    print(f'The upper quartile for {treatment} is: {upperq}')
    print(f"For drug {treatment} values below {lower_bound} could be outliers")
    print(f"For drug {treatment} values above {upper_bound} could be outliers")

    # Quantitative outliers. Use of PIPE to concatenate results for over upperbound and under lowerbound

    num_of_outliers = (final_vol.loc[(drug_df['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (drug_df['Tumor Volume (mm3)'] <= lower_bound)]).count()

    print(f'Number of outliers for {treatment} are: {num_of_outliers}')
# Out:
#
# The interquartile range for Capomulin is: 7.781863460000004
# The lower quartile for Capomulin is: 32.37735684
# The upper quartile for Capomulin is: 40.1592203
# For drug Capomulin values below 20.70456164999999 could be outliers
# For drug Capomulin values above 51.83201549 could be outliers
# Number of outliers for Capomulin are: 0
#
# The interquartile range for Ramicane is: 7.527130082499998
# The lower quartile for Ramicane is: 30.981175224999998
# The upper quartile for Ramicane is: 38.508305307499995
# For drug Ramicane values below 19.690480101250003 could be outliers
# For drug Ramicane values above 49.79900043124999 could be outliers
# Number of outliers for Ramicane are: 0
#
# The interquartile range for Infubinol is: 4.9311172099999965
# The lower quartile for Infubinol is: 62.75445141
# The upper quartile for Infubinol is: 67.68556862
# For drug Infubinol values below 55.35777559500001 could be outliers
# For drug Infubinol values above 75.08224443499999 could be outliers
# Number of outliers for Infubinol are: 0
#
# The interquartile range for Ceftamin is: 6.093590140000003
# The lower quartile for Ceftamin is: 61.43389223
# The upper quartile for Ceftamin is: 67.52748237
# For drug Ceftamin values below 52.29350701999999 could be outliers
# For drug Ceftamin values above 76.66786758 could be outliers
# Number of outliers for Ceftamin are: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# Boxplot
fig1, ax1 = plt.subplots(figsize=(15, 4))                # Boxplot and total size of graph
ax1.set_title('Tumor Volume by Treatment', fontsize =20) # Title and fontsize
ax1.set_ylabel('Final Tumor Volume (mm3)',fontsize = 16) # label for y axis and fontsize
ax1.set_xlabel('Drug Regimen',fontsize = 16)             # label for x axis and fontsize 
ax1.boxplot(list_tumor_vol, widths = 0.4,vert=True)

# text for ticks and fontsize
plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'], fontsize = 14) 

plt.ylim(10, 80) # limit of y axis
plt.grid()       # grid for reference 

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# Identify data points of a mouse treated with Capomulin.
# NOTE: tried to open an input field and then compare it with a Mouse ID in the list but got many problems
# restarted kernel, etc. Have no more time to experiment. Finally got a specific Mouse ID to plot
mouse_plot = pick_drugs_df.loc[pick_drugs_df['Mouse ID'] == 'x401']

# Plot a line chart with the time values on the x-axis and the tumor volume values on the y-axis
# Add labels and title to plot

plt.figure(figsize=(14, 8))                     # Set up total size of graph
plt.xlabel("Timepoint (Days)",fontsize =16)     # x label and fontsize for it
plt.ylabel("Tumor Volume (mm3)",fontsize =16)   # y label and fontsize for it
plt.xticks(fontsize=12)                         # fontsize for values in x tick marks
plt.xticks(np.arange(0, 50, 5.0))               # setup ticks frequency of 5 for x axis
plt.yticks(fontsize=12)                         # fontsize for values in y tick marks
plt.ylim(25, 48)                                # y axis value limits for graph
plt.xlim(-1, 46)                                # x axis value limits for graph

plt.grid()   # show grid for reference

plt.title("Evolution of tumor vs time of Mouse x401 treated with Capomulin",fontsize =22) # Title and fontsize

plt.plot(mouse_plot['Timepoint'],          # produce plot of time vs tumor vol
         mouse_plot['Tumor Volume (mm3)'], 
         marker = '^',                     # funny triangle marker
         color="r",                        # red color
         markersize=10)                    # bigger marker size

# Display plot
plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# Get those only using Capomulin drug regimen from previous dataframe
capomulin_df = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin']
# capomulin_df

# Calculate average tumor vol and weight
avg_vol_df =capomulin_df.groupby(['Mouse ID']).mean()

plt.figure(figsize=(12, 5))                                        # Set up total size of graph

plt.title('Mouse Weight Versus Average Tumor Volume',fontsize =20) # Title and fontsize
plt.xlabel('Mouse weight (g)',fontsize =15)                        # x label and fontsize for it
plt.ylabel('Average Tumor Volume (mm3)',fontsize =15)              # y label and fontsize for it
plt.xticks(fontsize=13)                                            # fontsize for values in x tick marks
plt.yticks(fontsize=13)                                            # fontsize for values in y tick marks

plt.grid() # grid for reference


plt.scatter(avg_vol_df['Weight (g)'],          # produce scatter plot for weight vs Tumor volume
            avg_vol_df['Tumor Volume (mm3)'],
            s=80,                              # marker size
            color="red",                       # marker color
            edgecolors='black')                # Adding edge for markers to better contrast


plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen


# Get weight and tumor volume from previous dataframe
weight = avg_vol_df['Weight (g)']
vol = avg_vol_df['Tumor Volume (mm3)']

# Calculate the correlation coefficient between mouse weight and average tumor volume
correlation = st.pearsonr(weight,vol)                 # pearson method
correlation = round(correlation[0],2)                 # round value with 2 decimals
# Print answer of above calculation
print(f"Correlation between weight and average tumor volume using Capomulin drug is {correlation}")

# Calculate linear regression for above values weight and tumor volume
(slope, intercept, rvalue, pvalue, stderr) = linregress(weight, vol)
regress_values = weight * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) # equation of a line y = mx + b 

plt.figure(figsize=(14, 8))                                        # Set up total size of graph

# Plot linear regression on top of scatter plot ----------------------------------------------------
# Plot scatter
plt.scatter(weight,vol,
            s=100, 
            color="yellow",
            edgecolors='black')

# plot linear regression with variables
plt.plot(weight,regress_values,"r-")

# Show formula for linear regression
plt.annotate(line_eq,(18.1,41),              # position of line formula within x, y values in graph
             fontsize=14.5,
             color="red")  

# Add labels and title to plot
plt.xlabel("Weight (g)",fontsize =16)
plt.ylabel("Average Tumor Volume (mm3)",fontsize =16)
plt.title('Linear regression of mice weight vs average tumor volume using Capomulin',fontsize =18)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.grid()


plt.show()
# Out:
# Correlation between weight and average tumor volume using Capomulin drug is 0.84
