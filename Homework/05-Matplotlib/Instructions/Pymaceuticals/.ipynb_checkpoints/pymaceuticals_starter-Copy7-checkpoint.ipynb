# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset keeping every value in all raws
mouse_dataset_df = pd.merge(mouse_metadata, study_results, how = "outer", on='Mouse ID' )


# Display the data table for preview
mouse_dataset_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
# Checking the number of mice.
num_of_mice = mouse_dataset_df['Mouse ID'].nunique()
num_of_mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_rows_df = mouse_dataset_df[mouse_dataset_df.duplicated(['Mouse ID', 'Timepoint'])]
# print("Duplicate Rows based on 2 columns are:", duplicate_rows_df, sep='\n')
print("Duplicate Rows based on 2 columns are:")
duplicate_rows_df
# Out:
# Duplicate Rows based on 2 columns are:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID.
# duplicate_rows_df
duplicate_rows_df = mouse_dataset_df[mouse_dataset_df.duplicated(['Mouse ID', 'Timepoint'], 
                                                                 keep=False)]
duplicate_rows_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
# result_df = source_df.drop_duplicates(keep=False)
# print('Result DataFrame:\n', result_df)

# clean_df = mouse_dataset_df.drop_duplicates(keep=False)
# clean_df

# mouse_dataset_df.drop_duplicates(subset=['Mouse ID', 'Timepoint'], keep=False)
# mouse_dataset_df

clean_df = mouse_dataset_df.loc[mouse_dataset_df["Mouse ID"] != "g989"]
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
# Checking the number of mice in the clean DataFrame.
num_of_mice_clean_df = clean_df['Mouse ID'].nunique()
num_of_mice_clean_df
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties 
# of each drug regimen: 
summary_stats_df = clean_df.groupby('Drug Regimen')
# summary_stats_df.head()

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
tumor_vol_mean = summary_stats_df['Tumor Volume (mm3)'].mean()
tumor_vol_median = summary_stats_df['Tumor Volume (mm3)'].median()
tumor_vol_stdev = summary_stats_df['Tumor Volume (mm3)'].std()
tumor_vol_sem = summary_stats_df['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary dataframe.

summary_groupby_df = pd.DataFrame({'Mean': tumor_vol_mean, 'Median': tumor_vol_median,
                                   'Std Deviation': tumor_vol_stdev, 'SEM': tumor_vol_sem})

summary_groupby_df
# Out:
#                    Mean     Median  Std Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809       4.994774  0.329346
# Ceftamin      52.591172  51.776157       6.268188  0.469821
# Infubinol     52.884795  51.820584       6.567243  0.492236
# Ketapril      55.235638  53.698743       8.279709  0.603860
# Naftisol      54.331565  52.509285       8.134708  0.596466
# Placebo       54.033581  52.288934       7.821003  0.581331
# Propriva      52.320930  50.446266       6.622085  0.544332
# Ramicane      40.216745  40.673236       4.846308  0.320955
# Stelasyn      54.233149  52.431737       7.710419  0.573111
# Zoniferol     53.236507  51.818479       6.966589  0.516398

# %%
# Using the aggregation method, produce the same summary statistics in a single line

total_tumor_vol_mean = summary_groupby_df['Mean'].mean()
total_tumor_vol_median = summary_groupby_df['Median'].median()
total_tumor_vol_std = summary_groupby_df['Std Deviation'].mean()
total_tumor_vol_sem = summary_groupby_df['SEM'].mean()

total_tumor_vol_mean = round(total_tumor_vol_mean, 3)
total_tumor_vol_median = round(total_tumor_vol_median, 3)
total_tumor_vol_std = round(total_tumor_vol_std, 3)
total_tumor_vol_sem = round(total_tumor_vol_sem, 3)


# tumor_vol_mean = summary_stats_df['Tumor Volume (mm3)'].mean()
# tumor_vol_median = summary_stats_df['Tumor Volume (mm3)'].median()
# tumor_vol_stdev = summary_stats_df['Tumor Volume (mm3)'].std()
# tumor_vol_sem = summary_stats_df['Tumor Volume (mm3)'].sem()


# total_tumor_vol_mean
# total_tumor_vol_median
# total_tumor_vol_std
# total_tumor_vol_sem

arr = np.array(['Mean:',total_tumor_vol_mean, 'Median:',total_tumor_vol_median, 
                'Std Deviation:',total_tumor_vol_std,'SEM:', total_tumor_vol_sem])
print(*arr, sep = '   ')
# Out:
# Mean:   50.976   Median:   51.82   Std Deviation:   6.821   SEM:   0.503

# %% [markdown]
# ## Bar and Pie Charts

# %%
# clean_df.columns

# %%
# Generate a bar plot showing the total number of measurements taken 
# on each drug regimen using pandas.
# ya teniamos groupedby y clean, lo reusamos
# num_of_meas_by_drug = clean_df.groupby(["Drug Regimen"]).count()["Timepoint"] 
num_of_meas_by_drug = pd.DataFrame(summary_stats_df.count())

plot_with_pandas = num_of_meas_by_drug.plot.bar(width=0.5, figsize=(12,6), color='r',
                                                 fontsize = 12, legend=False)

# plot_with_pandas = num_of_meas_by_drug.plot.bar(kind='bar', title="Number of Measurements by Drug Regimen", color="r")
# Set labels for axes
plot_with_pandas.set_xlabel("Drug Regimen",fontsize = 16, color='b')
plot_with_pandas.set_ylabel("Number of Data Points",fontsize = 16, color='b')
plot_with_pandas.set_title("Number of Data Points for Each Treatment Regimen",fontsize = 18)

# plt.tight_layout()
plt.show()

# %%
# num_of_meas_by_drug.columns

# %%
# Generate a bar plot showing the total number of measurements taken 
# on each drug regimen using pyplot.

# Using previous groupby dataframe already obtained
num_of_meas_by_drug = clean_df.groupby(["Drug Regimen"]).count()["Mouse ID"] 


# Set x axis and tick locations
x_axis = np.arange(len(num_of_meas_by_drug))
tick_locations = [value for value in x_axis]

# BEFORE set figure size to adjust for space README
plt.figure(figsize=(12,6))
           
# thickness = width
plt.bar(x_axis, num_of_meas_by_drug, color='r', align="center", width=0.55)

# Playing with aesthetics. 45 degrees
plt.xticks(tick_locations, list(num_of_meas_by_drug.index), rotation=45, fontsize = 12)
# Set x and y limits
plt.xlim(-0.7, len(x_axis)-0.2)
# max value y axis
plt.ylim(0, max(num_of_meas_by_drug)*1.08)

# Set a Title and labels

plt.xlabel("Drug Regimen",fontsize = 16, color='b')
plt.ylabel("Number of Treatments",fontsize = 16, color='b')
plt.title("Number of Measurements by Drug Regimen",fontsize = 18)



# # column_name = ["Drug Regimen"]
# # plt.legend(column_name,loc="best")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# Identify distribution of data by sex
sex_data = clean_df['Sex'].value_counts()

# sex_pie = sex_data.plot(kind="pie", autopct="%1.2f%%", startangle=45, title='Female vs. Male mice', fontsize=14)
sex_pie = sex_data.plot(kind="pie", 
                        autopct='%.2f', 
                        colors =["yellow","orange"],
                        shadow=True,
                        startangle=45, 
                        fontsize=14)



# plt.title('Female vs. Male mice',fontsize = 16)
sex_pie.set_title('Male vs. Female mice',fontsize = 16)

# Hide the 'y' label apper the word "sex" don't know why 
sex_pie.set_ylabel('')

sex_pie

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

#List the values of each section of the pie chart
x_y = sex_data

# Create Labels for the sections of the pie
labels = ["Female","Male"]



#Set colors for each section of the pie
colors = ['yellow', 'orange']


#Create the pie chart based upon the values 
# fig1, ax1 = plt.subplots(figsize=(15, 10))
plt.pie(x_y, 
        labels=labels, 
        colors=colors, 
        autopct='%.2f', 
        shadow=True, 
        textprops = {"fontsize":14}, # Font size of text in pie chart
        startangle=45,)

plt.title('Male vs Female mice', fontsize = 16)

#Set equal axis
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# tumor_vol_df = clean_df.groupby(['Mouse ID', 'Tumor Volume (mm3)'])
reduced_df = clean_df[['Mouse ID','Drug Regimen','Timepoint', 'Tumor Volume (mm3)']]
reduced_df

#-----------------------------------

# Select only certain drug regimens

capomulin_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Capomulin",:]
ramicane_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Ramicane", :]
infubinol_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Infubinol", :]
ceftamin_df = reduced_df.loc[reduced_df["Drug Regimen"] == "Ceftamin", :]

# append
pick_drugs_df = capomulin_df
pick_drugs_df = pick_drugs_df.append(ramicane_df, ignore_index=True)
pick_drugs_df = pick_drugs_df.append(infubinol_df, ignore_index=True)
pick_drugs_df = pick_drugs_df.append(ceftamin_df, ignore_index=True)
# pick_drugs_df = drop_drugs_df.append(ramicane_df, ignore_index=True)
# pick_drugs_df = drop_drugs_df.append(infubinol_df, ignore_index=True)
# pick_drugs_df = drop_drugs_df.append(ceftamin_df, ignore_index=True)


# pd.set_option("display.max_rows", None, "display.max_columns", None)
# drop_drugs_df
  
# Start by getting the last (greatest) timepoint for each mouse
max_timepoint_df = pick_drugs_df[pick_drugs_df['Timepoint'] == pick_drugs_df['Timepoint'].max()]
#Enseño este?
# max_timepoint_df

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint--------------

# Rename columns to avoid conflicts
final_tumor_vol_df = max_timepoint_df.rename(columns={"Timepoint": "Max. timepoint", 
                                                               "Tumor Volume (mm3)": "Final tumor volume"})

# Drop unnecesary column that will be repeated after merging
final_tumor_vol_df = final_tumor_vol_df.drop(columns=['Drug Regimen'])

# final_tumor_vol_df

# Merge
clean_data_merged_df = pd.merge(clean_df, final_tumor_vol_df, on='Mouse ID')

# tabla full o no
pd.set_option("display.max_rows", None, "display.max_columns", None)
# clean_data_merged_df
max_timepoint_df
# Out:
#     Mouse ID Drug Regimen  Timepoint  Tumor Volume (mm3)
# 9       s185    Capomulin         45           23.343598
# 19      x401    Capomulin         45           28.484033
# 29      m601    Capomulin         45           28.430964
# 44      u364    Capomulin         45           31.023923
# 54      y793    Capomulin         45           31.896238
# 64      r554    Capomulin         45           32.377357
# 74      m957    Capomulin         45           33.329098
# 84      t565    Capomulin         45           34.455298
# 94      i738    Capomulin         45           37.311846
# 104     w914    Capomulin         45           36.041047
# 114     g288    Capomulin         45           37.074024
# 124     l897    Capomulin         45           38.846876
# 134     b742    Capomulin         45           38.939633
# 144     b128    Capomulin         45           38.982878
# 162     j119    Capomulin         45           38.125164
# 175     v923    Capomulin         45           40.658124
# 185     g316    Capomulin         45           40.159220
# 195     s710    Capomulin         45           40.728578
# 205     l509    Capomulin         45           41.483008
# 215     r944    Capomulin         45           41.581521
# 225     i557    Capomulin         45           47.685963
# 239     k403     Ramicane         45           22.050126
# 249     g791     Ramicane         45           29.128472
# 259     s508     Ramicane         45           30.276232
# 269     m546     Ramicane         45           30.564625
# 279     z578     Ramicane         45           30.638696
# 289     j913     Ramicane         45           31.560470
# 299     n364     Ramicane         45           31.095335
# 309     c758     Ramicane         45           33.397653
# 319     a644     Ramicane         45           32.978522
# 329     i177     Ramicane         45           33.562402
# 339     j989     Ramicane         45           36.134852
# 349     a520     Ramicane         45           38.810366
# 359     r811     Ramicane         45           37.225650
# 369     i334     Ramicane         45           36.374510
# 387     d251     Ramicane         45           37.311236
# 404     a411     Ramicane         45           38.407618
# 414     e662     Ramicane         45           40.659006
# 424     u196     Ramicane         45           40.667713
# 434     q597     Ramicane         45           45.220869
# 444     a444     Ramicane         45           43.047543
# 467     a203    Infubinol         45           67.973419
# 477     a251    Infubinol         45           65.525743
# 494     a685    Infubinol         45           66.083066
# 504     c139    Infubinol         45           72.226731
# 523     e476    Infubinol         45           62.435404
# 533     f345    Infubinol         45           60.918767
# 552     k483    Infubinol         45           66.196912
# 625     y163    Infubinol         45           67.685569
# 635     z581    Infubinol         45           62.754451
# 645     a275     Ceftamin         45           62.999356
# 675     j296     Ceftamin         45           61.849023
# 685     k210     Ceftamin         45           68.923185
# 695     l471     Ceftamin         45           67.748662
# 715     l661     Ceftamin         45           59.851956
# 725     l733     Ceftamin         45           64.299830
# 735     o287     Ceftamin         45           59.741901
# 745     p438     Ceftamin         45           61.433892
# 772     w151     Ceftamin         45           67.527482
# 783     x581     Ceftamin         45           64.634949
# 793     x822     Ceftamin         45           61.386660
# 803     y769     Ceftamin         45           68.594745
# 813     y865     Ceftamin         45           64.729837

# %%
# ver tabla maximos
# print(max_timepoint_df)

# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
list_tumor_vol = []

for treatment in treatments:
    
#     temp_df = max_timepoint_df.loc[max_timepoint_df['Drug Regimen'] == treatment]
# temp_df
    drug_df = max_timepoint_df[max_timepoint_df['Drug Regimen'] == treatment]
  
    
#   Drop unnecesary column that will be repeated after merging. Timepoint is the max
    drug_df = drug_df.drop(columns=['Timepoint'])
#     drug_df = drug_df.reset_index()
    
#     print(drug_df)

    # Create a series that consists of all final volume values for each regimen
    final_vol = drug_df['Tumor Volume (mm3)']
    list_tumor_vol.append(final_vol)

# print(final_vol)
# # Calculate the IQR and quantitatively determine if there are any potential outliers.

    quartiles = final_vol.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq

    #     print("                                                   ")
    #     print(treatment, iqr, upperq, lowerq)

    print("                                                   ")
    print(f'The interquartile range for {treatment} is: {iqr}')

        # Find upper and lower bounds to help identify outliers for each regimen ASTONISHING CONCLUSION
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f'The lower quartile for {treatment} is: {lowerq}')
    print(f'The upper quartile for {treatment} is: {upperq}')
    print(f"For drug {treatment} values below {lower_bound} could be outliers")
    print(f"For drug {treatment} values above {upper_bound} could be outliers")

    # Quantitative outliers. Use of PIPE README

    num_of_outliers = (final_vol.loc[(drug_df['Tumor Volume (mm3)'] >= upper_bound) | 
                                        (drug_df['Tumor Volume (mm3)'] <= lower_bound)]).count()

    print(f'Number of outliers for {treatment} is: {num_of_outliers}')
# Out:
#
# The interquartile range for Capomulin is: 7.781863460000004
# The lower quartile for Capomulin is: 32.37735684
# The upper quartile for Capomulin is: 40.1592203
# For drug Capomulin values below 20.70456164999999 could be outliers
# For drug Capomulin values above 51.83201549 could be outliers
# Number of outliers for Capomulin is: 0
#
# The interquartile range for Ramicane is: 7.527130082499998
# The lower quartile for Ramicane is: 30.981175224999998
# The upper quartile for Ramicane is: 38.508305307499995
# For drug Ramicane values below 19.690480101250003 could be outliers
# For drug Ramicane values above 49.79900043124999 could be outliers
# Number of outliers for Ramicane is: 0
#
# The interquartile range for Infubinol is: 4.9311172099999965
# The lower quartile for Infubinol is: 62.75445141
# The upper quartile for Infubinol is: 67.68556862
# For drug Infubinol values below 55.35777559500001 could be outliers
# For drug Infubinol values above 75.08224443499999 could be outliers
# Number of outliers for Infubinol is: 0
#
# The interquartile range for Ceftamin is: 6.093590140000003
# The lower quartile for Ceftamin is: 61.43389223
# The upper quartile for Ceftamin is: 67.52748237
# For drug Ceftamin values below 52.29350701999999 could be outliers
# For drug Ceftamin values above 76.66786758 could be outliers
# Number of outliers for Ceftamin is: 0

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
mouse_df = max_timepoint_df

# Drop unnecesary column that will be repeated after merging
# final_tumor_vol_df = final_tumor_vol_df.drop(columns=['Drug Regimen'])

mouse_df = mouse_df.drop(columns=['Timepoint']).reset_index()

print(mouse_df)

# print df.to_string(index=False)
# # ask user to choose a mouse to check his tumor data
# question = ("Choose a Mouse ID from previous list to check its tumor data: ")
# mouse = input()

# # if mouse.lower() == mouse_df['Mouse ID']

# # ***NOTE*** must run previous cells in order for this cell to work

# # # Edit outliers on boxplot for visibility
# # flierprops = dict(marker='o', markerfacecolor='r', markersize=8, markeredgecolor='black')

# # # Plot boxplot
# # plt.boxplot(list_tumor_vol, flierprops=flierprops)

# # # Add title and labels to boxplot
# # plt.title('Final Tumor Volume by Drug')
# # plt.ylabel('Final Tumor Volume (mm3)')
# # plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'])

# # plt.show()

# # fig1, ax1 = plt.subplots()

# fig1, ax1 = plt.subplots(figsize=(15, 4))
# ax1.set_title('Tumor Volume at Input',fontsize =20)
# ax1.set_ylabel('Final Tumor Volume (mm3)',fontsize = 16)
# ax1.set_xlabel('Drug Regimen',fontsize = 16)
# ax1.boxplot(list_tumor_vol, widths = 0.4,vert=True)
# plt.xticks([1, 2, 3, 4], ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin'], fontsize = 14)

# plt.ylim(10, 80)
# plt.grid()


# # plt.tight_layout() 

# plt.show()
# Out:
#     index Mouse ID Drug Regimen  Tumor Volume (mm3)
# 0       9     s185    Capomulin           23.343598
# 1      19     x401    Capomulin           28.484033
# 2      29     m601    Capomulin           28.430964
# 3      44     u364    Capomulin           31.023923
# 4      54     y793    Capomulin           31.896238
# 5      64     r554    Capomulin           32.377357
# 6      74     m957    Capomulin           33.329098
# 7      84     t565    Capomulin           34.455298
# 8      94     i738    Capomulin           37.311846
# 9     104     w914    Capomulin           36.041047
# 10    114     g288    Capomulin           37.074024
# 11    124     l897    Capomulin           38.846876
# 12    134     b742    Capomulin           38.939633
# 13    144     b128    Capomulin           38.982878
# 14    162     j119    Capomulin           38.125164
# 15    175     v923    Capomulin           40.658124
# 16    185     g316    Capomulin           40.159220
# 17    195     s710    Capomulin           40.728578
# 18    205     l509    Capomulin           41.483008
# 19    215     r944    Capomulin           41.581521
# 20    225     i557    Capomulin           47.685963
# 21    239     k403     Ramicane           22.050126
# 22    249     g791     Ramicane           29.128472
# 23    259     s508     Ramicane           30.276232
# 24    269     m546     Ramicane           30.564625
# 25    279     z578     Ramicane           30.638696
# 26    289     j913     Ramicane           31.560470
# 27    299     n364     Ramicane           31.095335
# 28    309     c758     Ramicane           33.397653
# 29    319     a644     Ramicane           32.978522
# 30    329     i177     Ramicane           33.562402
# 31    339     j989     Ramicane           36.134852
# 32    349     a520     Ramicane           38.810366
# 33    359     r811     Ramicane           37.225650
# 34    369     i334     Ramicane           36.374510
# 35    387     d251     Ramicane           37.311236
# 36    404     a411     Ramicane           38.407618
# 37    414     e662     Ramicane           40.659006
# 38    424     u196     Ramicane           40.667713
# 39    434     q597     Ramicane           45.220869
# 40    444     a444     Ramicane           43.047543
# 41    467     a203    Infubinol           67.973419
# 42    477     a251    Infubinol           65.525743
# 43    494     a685    Infubinol           66.083066
# 44    504     c139    Infubinol           72.226731
# 45    523     e476    Infubinol           62.435404
# 46    533     f345    Infubinol           60.918767
# 47    552     k483    Infubinol           66.196912
# 48    625     y163    Infubinol           67.685569
# 49    635     z581    Infubinol           62.754451
# 50    645     a275     Ceftamin           62.999356
# 51    675     j296     Ceftamin           61.849023
# 52    685     k210     Ceftamin           68.923185
# 53    695     l471     Ceftamin           67.748662
# 54    715     l661     Ceftamin           59.851956
# 55    725     l733     Ceftamin           64.299830
# 56    735     o287     Ceftamin           59.741901
# 57    745     p438     Ceftamin           61.433892
# 58    772     w151     Ceftamin           67.527482
# 59    783     x581     Ceftamin           64.634949
# 60    793     x822     Ceftamin           61.386660
# 61    803     y769     Ceftamin           68.594745
# 62    813     y865     Ceftamin           64.729837

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
