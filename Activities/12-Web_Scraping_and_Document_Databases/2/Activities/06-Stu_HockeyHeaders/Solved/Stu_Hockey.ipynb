# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/news'

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('div', class_='article-item__top')

# loop over results to get article data
for result in results:
    # scrape the article header 
    header = result.find('h1', class_='article-item__headline').text
    
    # scrape the article subheader
    subheader = result.find('h2', class_='article-item__subheader').text
    
    # scrape the datetime
    datetime = result.find('span', class_='article-item__date')['data-date'] 
    
    # get only the date from the datetime
    date = datetime.split('T')[0]
    
    # print article data
    print('-----------------')
    print(header)
    print(subheader)
    print(date)

    # Dictionary to be inserted into MongoDB
    post = {
        'header': header,
        'subheader': subheader,
        'date': date,
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Penguins shut out Bruins, move into first in MassMutual East Division
# Jarry makes 30 saves, Guentzel scores only goal in Pittsburgh's fourth straight win
# 2021-04-25
# -----------------
# Stanley Cup Playoffs Buzz: Rangers gain on Bruins in East
# Penguins move into first; Lightning pick up ground in Central
# 2021-04-26
# -----------------
# Shaw ends playing career, won Stanley Cup twice with Blackhawks
# Forward was on long-term injured reserve with concussion
# 2021-04-26
# -----------------
# Hedman scores 10 seconds into OT, Lightning defeat Blue Jackets
# Tampa Bay gains ground in Central; Korpisalo leaves with lower-body injury
# 2021-04-25
# -----------------
# Ovechkin has lower-body injury, may not play for Capitals vs. Islanders
# Forward might miss second straight game Tuesday, is one goal from tying Dionne for fifth all-time
# 2021-04-25
# -----------------
# Lafreniere's confidence growing for Rangers
# Rookie forward's effort, understanding of offense has 'elevated to an NHL level,' coach says
# 2021-04-26
# -----------------
# Zibanejad's hat trick helps Rangers top Sabres, gain in East
# Kakko scores twice, Fox has three assists for New York
# 2021-04-25
# -----------------
# Giroux scores twice in third, Flyers hand Devils 10th straight loss
# Forward ties game with goals 22 seconds apart; Elliott makes 29 saves
# 2021-04-25
# -----------------
# Gostisbehere out 7-10 days for Flyers with knee injury
# Defenseman has MCL strain, goalie Hart 'taking a little longer' than expected
# 2021-04-25
# -----------------
# Fantasy hockey top 10 waiver wire pickups
# Burakovsky, Foligno playing on top lines; Bennett covers categories for Panthers
# 2021-04-26
# -----------------
# Stanley Cup Playoffs clinching scenarios for April 26
# Hurricanes, Panthers, Lightning can earn berth
# 2021-04-26
# -----------------
# Backes contemplating retirement from NHL after this season with Ducks
# Forward has scored four points in 14 games, turns 37 on May 1
# 2021-04-25
# -----------------
# Tavares using platform with Maple Leafs to help Special Olympics Canada
# Captain passionate about raising funds, awareness for intellectually disabled children
# 2021-04-25
# -----------------
# Color of Hockey: Former goalie Buffalo inspiring Indigenous youth
# Dartmouth graduate strong voice for pursuing education, overcoming racism
# 2021-04-26
# -----------------
# Fantasy top 25 line rankings for 2020-21
# NHL.com lists best units in terms of past chemistry, rest-of-season potential
# 2021-04-25
# -----------------
# Stillman agrees to three-year contract with Blackhawks
# Defenseman gets $1.35 million annually, could have become restricted free agent
# 2021-04-25
# -----------------
# Former NHL goalie Brathwaite suits up as backup for AHL Silver Knights
# Now 48 years old, team's goaltending coach and veteran who played nine seasons in League acts as EBUG
# 2021-04-25
# -----------------
# Anisimov was ready to be emergency backup goalie for Senators
# EBUG could have been needed against Canucks after Forsberg, Murray were injured
# 2021-04-25
# -----------------
# What to Watch: Golden Knights set for big test against Avalanche
# Flames chasing Canadiens in North, Stars pursuing Predators in Central among highlights of upcoming week
# 2021-04-26
# -----------------
# Kassian week to week for Oilers with lower-body injury
# Forward left loss to Canadiens after check against Weber
# 2021-04-24
# -----------------
# Lightning receive jewel-encrusted Stanley Cup rings with hidden bling
# Sparkling bauble features 557 diamonds, 81 sapphires, plus twist top
# 2021-04-23
# -----------------
# Marleau's Sharks tribute video narrated by former teammate Thornton
# Longtime Sharks forward, now with Maple Leafs, lends voice to honor NHL games played leader
# 2021-04-25
# -----------------
# 2021 NHL Draft top 32 prospects include Power, Hughes, Guenther
# Defensemen from Michigan, NTDP, Edmonton forward lead list according to NHL.com's Mike G. Morreale
# 2021-04-23
# -----------------
# Kaprizov pulls off wild between-the-legs move before scoring goal
# Wild rookie sensation notches 20th of season after making incredible move
# 2021-04-24
# -----------------
# Barkov scores overtime game-winning goal without looking
# Panthers captain pulls the crafty no-look move and it works like a charm
# 2021-04-24
# -----------------
# Knight latest U.S.-born goalie success after NHL debut with Panthers
# USA Hockey coaching program building camaraderie, raising homegrown quality at position
# 2021-04-23
# -----------------
# Larkin, Bertuzzi each out for season for Red Wings with injury
# Center to be reevaluated in two weeks, forward may need surgery
# 2021-04-24
# -----------------
# Blue Jackets miss playoffs due to center issues, defensive play
# Late-season slump also reason postseason streak ends at four
# 2021-04-23
# -----------------
# Bogosian out at least four weeks for Maple Leafs with shoulder injury
# Defenseman likely to be sidelined for start of playoffs
# 2021-04-23
# -----------------
# NHL DFS player picks, projections, strategy
# Holtby unbeaten for Canucks since their return; more Monday fantasy targets
# 2021-04-26

# %%
# Display the MongoDB records created above
articles = db.articles.find()
for article in articles:
    print(article)
# Out:
# {'_id': ObjectId('5f85c6141473bf1962e97120'), 'header': 'Pietrangelo signs seven-year, $61.6 million contract with Golden Knights', 'subheader': 'Defenseman gets $8.8 million per season, won Stanley Cup in 2019 as Blues captain', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97121'), 'header': 'Pietrangelo 7-year, $61.6 million contract latest splash for Vegas', 'subheader': 'Golden Knights again show commitment to winning Cup by signing free agent defenseman', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6151473bf1962e97122'), 'header': 'Toffoli agrees to four-year, $17 million contract with Canadiens', 'subheader': 'Forward scored 24 goals for Kings, Canucks last season, won Stanley Cup in 2014', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97123'), 'header': 'Schmidt traded to Canucks by Golden Knights for draft pick', 'subheader': 'Defenseman has five seasons remaining on six-year contract; Vegas gets 2022 third-round choice', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97124'), 'header': 'Stuetzle, No. 3 pick in 2020 Draft by Senators, to have arm surgery', 'subheader': 'Forward out 6-8 weeks after sustaining injury training for German team', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6151473bf1962e97125'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97126'), 'header': "Hall teaming with Eichel on Sabres 'will be lethal,' coach says", 'subheader': "Krueger hoping free agent addition, young center can end Buffalo's playoff drought", 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97127'), 'header': 'Fleury staying with Golden Knights, will be part of tandem with Lehner', 'subheader': 'Three-time Stanley Cup-winning goalie not being traded', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97128'), 'header': 'Lafreniere, No. 1 pick in 2020 Draft, agrees to contract with Rangers', 'subheader': "Left wing will prepare for NHL training camp, won't return to junior team", 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97129'), 'header': 'NHL free agent signings fantasy roundup', 'subheader': 'Pietrangelo gains value with Golden Knights; impact of Toffoli joining Canadiens', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9712a'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9712b'), 'header': "Landeskog, Avalanche have 'started a dialogue' on contract extension", 'subheader': 'Forward scored 44 points last season, has one year remaining on current deal', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9712c'), 'header': 'Toews traded to Avalanche by Islanders', 'subheader': 'Defenseman is restricted free agent; New York receives two second-round picks', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9712d'), 'header': 'Five Questions with Bill Zito', 'subheader': 'Panthers GM discusses first offseason with new team, learning from Blue Jackets', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6151473bf1962e9712e'), 'header': 'Hoffman, Granlund among remaining unrestricted free agents', 'subheader': 'Dadonov, Galchenyuk, Vatanen also available', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9712f'), 'header': 'Hall signs one-year, $8 million contract with Sabres', 'subheader': 'Forward, 2018 Hart Trophy winner, scored 52 points for Coyotes, Devils last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97130'), 'header': 'Gustafsson signs one-year, $3 million contract with Flyers', 'subheader': 'Defenseman was unrestricted free agent, scored 29 points for Blackhawks, Flames last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97131'), 'header': 'Lafreniere will wear jersey No. 13 for Rangers', 'subheader': 'Top selection in 2020 NHL draft will be ninth player to wear it for New York', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97132'), 'header': "Hall jokes about breaking table, says 'Go Bills' in video to Buffalo fans", 'subheader': 'Newly signed forward fires up fan base after signing with Sabres', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97133'), 'header': "Lundqvist jokes about Ovechkin's 100th goal video", 'subheader': 'Now Capitals teammates, former Rangers goalie cracks wise about letting one by him', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97134'), 'header': "Toews says he's shocked by direction taken by Blackhawks: report", 'subheader': 'Captain points to Crawford being allowed to leave, Saad trade to Avalanche', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c6151473bf1962e97135'), 'header': 'Graves signs three-year contract to stay with Avalanche', 'subheader': 'Defenseman was restricted free agent, led NHL with plus-40 rating last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97136'), 'header': 'Top NHL restricted free agents for 2020-21 season', 'subheader': 'Barzal, Mantha, Sergachev among best remaining', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c6151473bf1962e97137'), 'header': 'Fantasy projection for Hall with Sabres', 'subheader': 'Left wing top 50 player with exposure to Eichel; Dahlin likely beneficiary', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c6151473bf1962e97138'), 'header': 'Janmark agrees to one-year, $2.25 million contract with Blackhawks', 'subheader': 'Forward was unrestricted free agent, helped Stars to Stanley Cup Final', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e97139'), 'header': 'NHL players file for salary arbitration', 'subheader': 'Georgiev, Olofsson, Bertuzzi among 26 on list; hearings scheduled to run Oct. 20-Nov. 8', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9713a'), 'header': 'Islanders energized by future home to open for start of 2021-22 season', 'subheader': 'Confident UBS Arena will attract free agents, add more buzz to Rangers rivalry', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9713b'), 'header': "Color of Hockey: Villegas feels like 'superwoman' on U.S. sled team", 'subheader': 'Amputee who fled native Venezuela finds outlet, purpose from competition', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9713c'), 'header': 'Faksa signs five-year, $16.25 million contract to stay with Stars', 'subheader': 'Forward was restricted free agent, helped Dallas advance to Stanley Cup Final', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6151473bf1962e9713d'), 'header': 'Oct. 13: Howe scores first NHL goal in eight years', 'subheader': 'Plus: NHL begins neutral-site games; Ducks, Predators earn initial wins', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6291473bf1962e9713e'), 'header': 'Pietrangelo signs seven-year, $61.6 million contract with Golden Knights', 'subheader': 'Defenseman gets $8.8 million per season, won Stanley Cup in 2019 as Blues captain', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9713f'), 'header': 'Pietrangelo 7-year, $61.6 million contract latest splash for Vegas', 'subheader': 'Golden Knights again show commitment to winning Cup by signing free agent defenseman', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6291473bf1962e97140'), 'header': 'Toffoli agrees to four-year, $17 million contract with Canadiens', 'subheader': 'Forward scored 24 goals for Kings, Canucks last season, won Stanley Cup in 2014', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97141'), 'header': 'Schmidt traded to Canucks by Golden Knights for draft pick', 'subheader': 'Defenseman has five seasons remaining on six-year contract; Vegas gets 2022 third-round choice', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97142'), 'header': 'Stuetzle, No. 3 pick in 2020 Draft by Senators, to have arm surgery', 'subheader': 'Forward out 6-8 weeks after sustaining injury training for German team', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6291473bf1962e97143'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97144'), 'header': "Hall teaming with Eichel on Sabres 'will be lethal,' coach says", 'subheader': "Krueger hoping free agent addition, young center can end Buffalo's playoff drought", 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97145'), 'header': 'Fleury staying with Golden Knights, will be part of tandem with Lehner', 'subheader': 'Three-time Stanley Cup-winning goalie not being traded', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97146'), 'header': 'Lafreniere, No. 1 pick in 2020 Draft, agrees to contract with Rangers', 'subheader': "Left wing will prepare for NHL training camp, won't return to junior team", 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97147'), 'header': 'NHL free agent signings fantasy roundup', 'subheader': 'Pietrangelo gains value with Golden Knights; impact of Toffoli joining Canadiens', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97148'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97149'), 'header': "Landeskog, Avalanche have 'started a dialogue' on contract extension", 'subheader': 'Forward scored 44 points last season, has one year remaining on current deal', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9714a'), 'header': 'Toews traded to Avalanche by Islanders', 'subheader': 'Defenseman is restricted free agent; New York receives two second-round picks', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9714b'), 'header': 'Five Questions with Bill Zito', 'subheader': 'Panthers GM discusses first offseason with new team, learning from Blue Jackets', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c6291473bf1962e9714c'), 'header': 'Hoffman, Granlund among remaining unrestricted free agents', 'subheader': 'Dadonov, Galchenyuk, Vatanen also available', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9714d'), 'header': 'Hall signs one-year, $8 million contract with Sabres', 'subheader': 'Forward, 2018 Hart Trophy winner, scored 52 points for Coyotes, Devils last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9714e'), 'header': 'Gustafsson signs one-year, $3 million contract with Flyers', 'subheader': 'Defenseman was unrestricted free agent, scored 29 points for Blackhawks, Flames last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9714f'), 'header': 'Lafreniere will wear jersey No. 13 for Rangers', 'subheader': 'Top selection in 2020 NHL draft will be ninth player to wear it for New York', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97150'), 'header': "Hall jokes about breaking table, says 'Go Bills' in video to Buffalo fans", 'subheader': 'Newly signed forward fires up fan base after signing with Sabres', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97151'), 'header': "Lundqvist jokes about Ovechkin's 100th goal video", 'subheader': 'Now Capitals teammates, former Rangers goalie cracks wise about letting one by him', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97152'), 'header': "Toews says he's shocked by direction taken by Blackhawks: report", 'subheader': 'Captain points to Crawford being allowed to leave, Saad trade to Avalanche', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c6291473bf1962e97153'), 'header': 'Graves signs three-year contract to stay with Avalanche', 'subheader': 'Defenseman was restricted free agent, led NHL with plus-40 rating last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97154'), 'header': 'Top NHL restricted free agents for 2020-21 season', 'subheader': 'Barzal, Mantha, Sergachev among best remaining', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c6291473bf1962e97155'), 'header': 'Fantasy projection for Hall with Sabres', 'subheader': 'Left wing top 50 player with exposure to Eichel; Dahlin likely beneficiary', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c6291473bf1962e97156'), 'header': 'Janmark agrees to one-year, $2.25 million contract with Blackhawks', 'subheader': 'Forward was unrestricted free agent, helped Stars to Stanley Cup Final', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97157'), 'header': 'NHL players file for salary arbitration', 'subheader': 'Georgiev, Olofsson, Bertuzzi among 26 on list; hearings scheduled to run Oct. 20-Nov. 8', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97158'), 'header': 'Islanders energized by future home to open for start of 2021-22 season', 'subheader': 'Confident UBS Arena will attract free agents, add more buzz to Rangers rivalry', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e97159'), 'header': "Color of Hockey: Villegas feels like 'superwoman' on U.S. sled team", 'subheader': 'Amputee who fled native Venezuela finds outlet, purpose from competition', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9715a'), 'header': 'Faksa signs five-year, $16.25 million contract to stay with Stars', 'subheader': 'Forward was restricted free agent, helped Dallas advance to Stanley Cup Final', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c6291473bf1962e9715b'), 'header': 'Oct. 13: Howe scores first NHL goal in eight years', 'subheader': 'Plus: NHL begins neutral-site games; Ducks, Predators earn initial wins', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b70'), 'header': 'Pietrangelo signs seven-year, $61.6 million contract with Golden Knights', 'subheader': 'Defenseman gets $8.8 million per season, won Stanley Cup in 2019 as Blues captain', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b71'), 'header': 'Pietrangelo 7-year, $61.6 million contract latest splash for Vegas', 'subheader': 'Golden Knights again show commitment to winning Cup by signing free agent defenseman', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b72'), 'header': 'Toffoli agrees to four-year, $17 million contract with Canadiens', 'subheader': 'Forward scored 24 goals for Kings, Canucks last season, won Stanley Cup in 2014', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b73'), 'header': 'Schmidt traded to Canucks by Golden Knights for draft pick', 'subheader': 'Defenseman has five seasons remaining on six-year contract; Vegas gets 2022 third-round choice', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b74'), 'header': 'Stuetzle, No. 3 pick in 2020 Draft by Senators, to have arm surgery', 'subheader': 'Forward out 6-8 weeks after sustaining injury training for German team', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b75'), 'header': 'NHL Free Agent Tracker', 'subheader': 'Complete list of signings by team, available players', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b76'), 'header': "Hall teaming with Eichel on Sabres 'will be lethal,' coach says", 'subheader': "Krueger hoping free agent addition, young center can end Buffalo's playoff drought", 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b77'), 'header': 'Fleury staying with Golden Knights, will be part of tandem with Lehner', 'subheader': 'Three-time Stanley Cup-winning goalie not being traded', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b78'), 'header': 'Lafreniere, No. 1 pick in 2020 Draft, agrees to contract with Rangers', 'subheader': "Left wing will prepare for NHL training camp, won't return to junior team", 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b79'), 'header': 'NHL free agent signings fantasy roundup', 'subheader': 'Pietrangelo gains value with Golden Knights; impact of Toffoli joining Canadiens', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b7a'), 'header': '2020-21 NHL Trade Tracker', 'subheader': 'Official deals since Oct. 1, 2020', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b7b'), 'header': "Landeskog, Avalanche have 'started a dialogue' on contract extension", 'subheader': 'Forward scored 44 points last season, has one year remaining on current deal', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b7c'), 'header': 'Toews traded to Avalanche by Islanders', 'subheader': 'Defenseman is restricted free agent; New York receives two second-round picks', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b7d'), 'header': 'Five Questions with Bill Zito', 'subheader': 'Panthers GM discusses first offseason with new team, learning from Blue Jackets', 'date': '2020-10-13'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b7e'), 'header': 'Hoffman, Granlund among remaining unrestricted free agents', 'subheader': 'Dadonov, Galchenyuk, Vatanen also available', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b7f'), 'header': 'Hall signs one-year, $8 million contract with Sabres', 'subheader': 'Forward, 2018 Hart Trophy winner, scored 52 points for Coyotes, Devils last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b80'), 'header': 'Gustafsson signs one-year, $3 million contract with Flyers', 'subheader': 'Defenseman was unrestricted free agent, scored 29 points for Blackhawks, Flames last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b81'), 'header': 'Lafreniere will wear jersey No. 13 for Rangers', 'subheader': 'Top selection in 2020 NHL draft will be ninth player to wear it for New York', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b82'), 'header': "Hall jokes about breaking table, says 'Go Bills' in video to Buffalo fans", 'subheader': 'Newly signed forward fires up fan base after signing with Sabres', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b83'), 'header': "Lundqvist jokes about Ovechkin's 100th goal video", 'subheader': 'Now Capitals teammates, former Rangers goalie cracks wise about letting one by him', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b84'), 'header': "Toews says he's shocked by direction taken by Blackhawks: report", 'subheader': 'Captain points to Crawford being allowed to leave, Saad trade to Avalanche', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b85'), 'header': 'Graves signs three-year contract to stay with Avalanche', 'subheader': 'Defenseman was restricted free agent, led NHL with plus-40 rating last season', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b86'), 'header': 'Top NHL restricted free agents for 2020-21 season', 'subheader': 'Barzal, Mantha, Sergachev among best remaining', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b87'), 'header': 'Fantasy projection for Hall with Sabres', 'subheader': 'Left wing top 50 player with exposure to Eichel; Dahlin likely beneficiary', 'date': '2020-10-11'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b88'), 'header': 'Janmark agrees to one-year, $2.25 million contract with Blackhawks', 'subheader': 'Forward was unrestricted free agent, helped Stars to Stanley Cup Final', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b89'), 'header': 'NHL players file for salary arbitration', 'subheader': 'Georgiev, Olofsson, Bertuzzi among 26 on list; hearings scheduled to run Oct. 20-Nov. 8', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b8a'), 'header': 'Islanders energized by future home to open for start of 2021-22 season', 'subheader': 'Confident UBS Arena will attract free agents, add more buzz to Rangers rivalry', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b8b'), 'header': "Color of Hockey: Villegas feels like 'superwoman' on U.S. sled team", 'subheader': 'Amputee who fled native Venezuela finds outlet, purpose from competition', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b8c'), 'header': 'Faksa signs five-year, $16.25 million contract to stay with Stars', 'subheader': 'Forward was restricted free agent, helped Dallas advance to Stanley Cup Final', 'date': '2020-10-12'}
# {'_id': ObjectId('5f85c66a12bdd3aaf14a1b8d'), 'header': 'Oct. 13: Howe scores first NHL goal in eight years', 'subheader': 'Plus: NHL begins neutral-site games; Ducks, Predators earn initial wins', 'date': '2020-10-13'}
